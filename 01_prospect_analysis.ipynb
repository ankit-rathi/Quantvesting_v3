# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Quantvesting_v3/blob/main/01_prospect_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quantvesting
#
# ## Prospect Analysis
#
# Interactive prospect-selection view backed entirely by the Quantvesting engine.

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=b537ce7bada8aa21d3af8383213652f0913d9f3743bc01631ef6c699f5c54be2
#   Stored in directory: /root/.cache/pip/wheels/5c/a1/5f/c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built ta
# ...

# %%
# 1. Environment & imports

from google.colab import drive
drive.mount('/content/drive')

import sys

PROJECT = "/content/drive/My Drive/quantvesting_v3"
sys.path.insert(0, PROJECT + "/src")

from quantvesting import (
    Quantvesting,
    load_config,
    load_all_data,
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2. Load configuration and data

config = load_config(
    PROJECT + "/config/strategy.yaml"
)

data = load_all_data(
    PROJECT + "/data"
)

qv = Quantvesting(config)

# %%
# 3. Run prospect analysis

df_prospects_features = qv.prospects(
    data,
    include_portfolio=False,
)

# %%
# 4. Interactive prospect view

qv.display_dataframe(
    df_prospects_features,
    sort_by="CumlRnk",
    ascending=True,
)
# Out:
# ...
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>Close</th>
#       <th>FTT</th>
#       <th>Dev%_200</th>
#       <th>Dev%_PE</th>
#       <th>Spread%</th>
#       <th>Curr_PE</th>
#       <th>MedPE</th>
#       <th>Conviction</th>
#       <th>Cyclical</th>
#       <th>...</th>
#       <th>Criteria</th>
#       <th>Strategy</th>
#       <th>Sales_Grwth%</th>
#       <th>Profit_Grwth%</th>
#       <th>Category</th>
#       <th>InFolio</th>
#       <th>MCap</th>
#       <th>MBQ</th>
#       <th>CFO_2_EBITDA%</th>
#       <th>ROE%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HDFCAMC</td>
# ...

# %% [markdown]
# ### Optional decision layer

# %%
# 5. Candidate actions

df_prospects_actions = qv.prospect_actions(
    df_prospects_features,
    top_n=10,
)

qv.display_dataframe(
    df_prospects_actions,
    sort_by="CumlRnk",
    ascending=True,
)
# Out:
# ...
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>Close</th>
#       <th>FTT</th>
#       <th>Dev%_200</th>
#       <th>Dev%_PE</th>
#       <th>Spread%</th>
#       <th>Curr_PE</th>
#       <th>MedPE</th>
#       <th>Conviction</th>
#       <th>Cyclical</th>
#       <th>...</th>
#       <th>Strategy</th>
#       <th>Sales_Grwth%</th>
#       <th>Profit_Grwth%</th>
#       <th>Category</th>
#       <th>InFolio</th>
#       <th>MCap</th>
#       <th>MBQ</th>
#       <th>CFO_2_EBITDA%</th>
#       <th>ROE%</th>
#       <th>Action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HDFCAMC</td>
# ...
