# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Quantvesting_v3/blob/main/notebooks/03_MY_DECISIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Quantvesting | My Decisions
#
# ## What deserves my attention?
#
# This notebook is the **decision-intelligence layer**. It does not repeat the executive portfolio dashboard. It focuses on holdings and opportunities where Quantvesting's deeper metrics — FTT, RRR, Risk, Conviction and allocation — provide useful context for review.
#
# > **Customer journey:** Monitor → identify attention → understand evidence → review capital efficiency.

# %%
# !pip install -q ta pyxirr matplotlib plotly ipywidgets
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.4/532.4 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 51.2 MB/s eta 0:00:00
#   Building wheel for ta (setup.py) ... done

# %% [markdown]
# ### 1. Environment & controls
#
# Enter the `PORTFOLIO_ID` when prompted. Keep `EOD_RUN=False` unless this is the final end-of-day snapshot.

# %%
from google.colab import drive
drive.mount("/content/drive")

import sys
PROJECT = "/content/drive/My Drive/quantvesting_v3"
MARKET_DATA_DIR = PROJECT + "/market_data"
PORTFOLIO_ID = input("Enter Portfolio ID (default: ankit): ").strip() or "ankit"
PORTFOLIO_DATA_DIR = PROJECT + f"/portfolio_data/{PORTFOLIO_ID}"
EOD_RUN = False

sys.path.insert(0, PROJECT + "/src")

from quantvesting import (
    Quantvesting, load_config, load_market_data, load_portfolio_data,
    create_run_id, PROSPECT_DISPLAY_COLUMNS, PORTFOLIO_DISPLAY_COLUMNS,
)

RUN_ID = create_run_id()
# Out:
# Mounted at /content/drive
# Enter Portfolio ID (default: ankit): vinod

# %%
config = load_config(PROJECT + "/config/strategy.yaml")
qv = Quantvesting(config)

# Optional shared-market refresh; leave False unless a new Screener XLSX arrived.
REFRESH_SCREENER = False
if REFRESH_SCREENER:
    qv.ingest_screener(MARKET_DATA_DIR)

market_data = load_market_data(MARKET_DATA_DIR)
portfolio_data = load_portfolio_data(PORTFOLIO_DATA_DIR, portfolio_id=PORTFOLIO_ID)

# %% [markdown]
# ### 2. Run the existing engine
#
# The notebook only orchestrates the existing prospect, portfolio and decision layers.

# %%
df_prospects = qv.prospects(
    market_data, portfolio_data=portfolio_data, include_portfolio=True,
    portfolio_id=PORTFOLIO_ID, run_id=RUN_ID,
)

df_portfolio, portfolio_summary = qv.portfolio(
    market_data, portfolio_data=portfolio_data, eod=EOD_RUN,
    portfolio_id=PORTFOLIO_ID, run_id=RUN_ID,
)

df_prospect_actions = qv.prospect_actions(df_prospects, top_n=10)
df_portfolio_actions = qv.portfolio_actions(df_portfolio)
df_rotation = qv.capital_rotation(df_prospects, df_portfolio)

# %% [markdown]
# ### 3. Portfolio attention
#
# Review holdings with active decision flags and the existing evidence generated by the decision engine. RRR/FTT context is shown here rather than on every notebook.

# %%
qv.display_dataframe(
    df_portfolio_actions,
    columns=[c for c in PORTFOLIO_DISPLAY_COLUMNS + ["Action", "ActionReason", "ActionEvidence"]
             if c in df_portfolio_actions.columns],
    sort_by="CurrAlloc%", ascending=False,
)
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>Today P/L%</th>
#       <th>Current P/L%</th>
#       <th>FTT%</th>
#       <th>OTT%</th>
#       <th>FTT Amt</th>
#       <th>Current P/L</th>
#       <th>Current</th>
#       <th>FTT</th>
#       <th>Dev%_PE</th>
#       <th>...</th>
#       <th>CumlRnk</th>
#       <th>RRR Ind</th>
#       <th>CurrAlloc%</th>
#       <th>Gained%</th>
#       <th>Criteria</th>
#       <th>Strategy</th>
#       <th>Category</th>
#       <th>Action</th>
#       <th>ActionReason</th>
#       <th>ActionEvidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>TCS</td>
#       <td>-0.69</td>
#       <td>-28.00</td>
#       <td>83.62</td>
#       <td>32.21</td>
#       <td>192660.0</td>
#       <td>-89600.0</td>
#       <td>230400.0</td>
#       <td>4230.71</td>
#       <td>-43.98</td>
#       <td>...</td>
#       <td>2.0</td>
#       <td>-0.47</td>
#       <td>42.48</td>
#       <td>16.85</td>
#       <td>X40</td>
#       <td>ATH</td>
#       <td>IT</td>
#       <td>HOLD</td>
#       <td>Thesis not yet at a configured review/target t...</td>
#       <td>Captured=-87% | Remaining upside=83.6%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>INFY</td>
#       <td>-0.03</td>
#       <td>-22.07</td>
#       <td>74.51</td>
#       <td>36.00</td>
#       <td>126294.0</td>
#       <td>-48000.0</td>
#       <td>169500.0</td>
#       <td>1972.00</td>
#       <td>-40.86</td>
#       <td>...</td>
#       <td>3.0</td>
#       <td>-0.38</td>
#       <td>31.25</td>
#       <td>14.69</td>
#       <td>X40</td>
#       <td>NTT</td>
#       <td>IT</td>
#       <td>HOLD</td>
#       <td>Thesis not yet at a configured review/target t...</td>
#       <td>Captured=-61% | Remaining upside=74.5%</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>HDFCBANK</td>
#       <td>0.77</td>
#       <td>-56.84</td>
#       <td>50.68</td>
#       <td>-34.97</td>
#       <td>72178.0</td>
#       <td>-187580.0</td>
#       <td>142420.0</td>
#       <td>1073.00</td>
#       <td>-29.51</td>
#       <td>...</td>
#       <td>26.0</td>
#       <td>-2.60</td>
#       <td>26.26</td>
#       <td>1.61</td>
#       <td>X40</td>
#       <td>BTT</td>
#       <td>BANKS</td>
#       <td>HOLD</td>
#       <td>Thesis not yet at a configured review/target t...</td>
#       <td>Captured=N/A | Remaining upside=50.7%</td>
#     </tr>
#   </tbody>
# </table>
# <p>3 rows × 23 columns</p>
# </div>

# %% [markdown]
# ### 4. Opportunity candidates relevant to decisions
#
# The prospect action table is intentionally limited to the candidates most relevant to decision review. The complete Quantvesting universe remains in `04_QUANTVESTING_OPPORTUNITIES.ipynb`.

# %%
qv.display_dataframe(
    df_prospect_actions,
    columns=[c for c in PROSPECT_DISPLAY_COLUMNS + ["Action", "Reason", "Evidence"]
             if c in df_prospect_actions.columns],
    sort_by="CumlRnk", ascending=True,
)
# Out:
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>FTT</th>
#       <th>Dev%_200</th>
#       <th>Dev%_PE</th>
#       <th>Spread%</th>
#       <th>Conviction</th>
#       <th>Cyclical</th>
#       <th>RSI_14</th>
#       <th>RSP</th>
#       <th>FTT%</th>
#       <th>...</th>
#       <th>Gained%</th>
#       <th>CumlRnk</th>
#       <th>ROE%/PE</th>
#       <th>Criteria</th>
#       <th>Strategy</th>
#       <th>Category</th>
#       <th>InFolio</th>
#       <th>Action</th>
#       <th>Reason</th>
#       <th>Evidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>INFY</td>
#       <td>1972.00</td>
#       <td>-12.13</td>
#       <td>-40.86</td>
#       <td>13.67</td>
#       <td>X-LC</td>
#       <td>NC</td>
#       <td
td>
#       <td>NA</td>
#       <td>BUY_CANDIDATE</td>
#       <td>High-ranked opportunity within the configured ...</td>
#       <td>CumlRnk=9</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>VBL</td>
#       <td>669.42</td>
#       <td>-13.09</td>
#       <td>-32.47</td>
#       <td>9.08</td>
#       <td>X-LC</td>
#       <td>NC</td>
#       <td>36.0</td>
#       <td>22.22</td>
#       <td>64.23</td>
#       <td>...</td>
#       <td>7.00</td>
#       <td>10.0</td>
#       <td>0.4</td>
#       <td>X40N</td>
#       <td>ATH</td>
#       <td>FMCG</td>
#       <td>NA</td>
#       <td>BUY_CANDIDATE</td>
#       <td>High-ranked opportunity within the configured ...</td>
#       <td>CumlRnk=10</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>RELIANCE</td>
#       <td>1952.00</td>
#       <td>-4.55</td>
#       <td>-6.35</td>
#       <td>5.91</td>
#       <td>X-LC</td>
#       <td>SC</td>
#       <td>55.0</td>
#       <td>76.04</td>
#       <td>47.66</td>
#       <td>...</td>
#       <td>5.02</td>
#       <td>11.0</td>
#       <td>0.4</td>
#       <td>XY25</td>
#       <td>BTT</td>
#       <td>REFINERIES</td>
#       <td>NA</td>
#       <td>WATCHLIST</td>
#       <td>Outside the current top-N opportunity set.</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NESTLEIND</td>
#       <td>1377.00</td>
#       <td>4.71</td>
#       <td>-10.52</td>
#       <td>8.98</td>
#       <td>X-LC</td>
#       <td>NC</td>
#       <td>37.0</td>
#       <td>21.53</td>
#       <td>-2.38</td>
#       <td>...</td>
#       <td>23.64</td>
#       <td>12.0</td>
#       <td>1.0</td>
#       <td>XY25</td>
#       <td>NTT</td>
#       <td>FMCG</td>
#       <td>NA</td>
#       <td>WATCHLIST</td>
#       <td>Outside the current top-N opportunity set.</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>HDFCLIFE</td>
#       <td>811.41</td>
#       <td>-14.49</td>
#       <td>-31.07</td>
#       <td>15.13</td>
#       <td>X-LC</td>
#       <td>NC</td>
#       <td>50.0</td>
#       <td>75.00</td>
#       <td>48.50</td>
#       <td>...</td>
#       <td>2.51</td>
#       <td>13.0</td>
#       <td>0.2</td>
#       <td>X40</td>
#       <td>ATH</td>
#       <td>INSURANCE</td>
#       <td>NA</td>
#       <td>WATCHLIST</td>
#       <td>Outside the current top-N opportunity set.</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>MARUTI</td>
#       <td>17120.06</td>
#       <td>-10.33</td>
#       <td>-13.15</td>
#       <td>4.38</td>
#       <td>X-LC</td>
#       <td>DC</td>
#       <td>28.0</td>
#       <td>12.15</td>
#       <td>34.87</td>
#       <td>...</td>
#       <td>4.19</td>
#       <td>14.0</td>
#       <td>0.5</td>
#       <td>XR</td>
#       <td>ATH</td>
#       <td>AUTO</td>
#       <td>NA</td>
#       <td>WATCHLIST</td>
#       <td>Outside the current top-N opportunity set.</td>

# %% [markdown]
# ### 5. Capital rotation review
#
# Capital rotation belongs here because it answers a decision question: **where might existing capital deserve a review relative to available opportunity?** It is advisory and does not issue an automatic sell instruction.

# %% [markdown]
# ### 6. Capital rotation review
#
# This is advisory only. It does not issue an automatic sell instruction.

# %%
if df_rotation.empty:
    print("No capital-rotation candidates at the current configured thresholds.")
else:
    display(df_rotation)
# Out:
# No capital-rotation candidates at the current configured thresholds.

# %% [markdown]
# ### Decision discipline
#
# Use this notebook to understand **what deserves review and why**, not as an automated trading instruction. The underlying Quantvesting methodology remains in the engine.
