# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Quantvesting_v3/blob/main/06_Portfolio_Assessment_Terminal_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Reusable user-input contract
#
# For each new user, replace **`data/myPortfolioStocks.csv`** with that user's portfolio in the same format.
#
# The notebook automatically uses the local portfolio file when present. Prospects, Screener and Investments can also be placed in `data/`; otherwise the existing GitHub sources remain available as fallback/demo data.

# %%
# Install notebook presentation dependencies
# !pip install pandas==2.2.3 -qq
# !pip install pyxirr -qq
# !pip install ta -qq
# !pip install yfinance==0.2.59 -qq
# !pip install plotly ipywidgets -qq

# %%
# Core libraries
import numpy as np
import pandas as pd
import datetime
import warnings
warnings.filterwarnings('ignore')

import yfinance as yfin
import ta
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import requests
import ipywidgets as widgets

from IPython.display import display, HTML, Markdown, clear_output

# %%
# Notebook runtime
import time
import datetime
import pytz

start_time = time.time()

def print_date_time():
    tz_ist = pytz.timezone('Asia/Kolkata')
    datetime_ist = datetime.datetime.now(tz_ist)
    print("Run date time (IST):", datetime_ist.strftime("%Y-%m-%d %H:%M:%S"))

RUN_STYLE = {
    "font_family": "Inter, Arial, sans-serif",
    "border_radius": "14px",
}

# %%
# function to get booked and reserved amount
def get_amt():
  # fetch the JSON data from the URL
  url = "https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/myPortfolioAmts.json"
  response = requests.get(url)
  pf_amts = response.json()  # parse the JSON data

  # extract values from the JSON
  py_booked_amt_dm = pf_amts["py_booked_amt_dm"]
  py_booked_amt_sv = pf_amts["py_booked_amt_sv"]
  cy_booked_amt_dm = pf_amts["cy_booked_amt_dm"]
  cy_booked_amt_sv = pf_amts["cy_booked_amt_sv"]
  reserve_amt_dm = pf_amts["reserve_amt_dm"]
  reserve_amt_sv = pf_amts["reserve_amt_sv"]

  # perform calculations
  py_booked_amt = py_booked_amt_dm + py_booked_amt_sv
  cy_booked_amt = cy_booked_amt_dm + cy_booked_amt_sv
  reserve_amt = reserve_amt_dm + reserve_amt_sv
  total_booked_amt = py_booked_amt + cy_booked_amt

  return total_booked_amt, reserve_amt, cy_booked_amt, py_booked_amt

gen_output = 0

# %%
# function to format the amount
def format_amt(number):
    abs_number = abs(number)

    if abs_number >= 1_00_00_000:  # Crores
        formatted_amt = f"{number / 1_00_00_000:.2f} C"
    elif abs_number >= 1_00_000:  # Lakhs
        formatted_amt = f"{number / 1_00_000:.2f} L"
    elif abs_number >= 1_000:  # Thousands
        formatted_amt = f"{number / 1_000:.2f} K"
    else:
        formatted_amt = f"{number:.2f}"

    return formatted_amt

# function to set start and end date
def get_start_end_date():
  start_date = (datetime.date.today() + datetime.timedelta(days=-365)).strftime('%Y-%m-%d')
  end_date = (datetime.date.today() + datetime.timedelta(days=1)).strftime('%Y-%m-%d')
  return start_date, end_date

# ============================================================
# DATA SOURCE CONFIGURATION
# ============================================================
# Recommended reusable layout:
#   ./data/myPortfolioStocks.csv
#   ./data/myProspectsScrips.csv
#   ./data/myScreenerDB.csv
#   ./data/myInvestments.csv
#
# Local files take precedence. GitHub is retained as fallback/demo.

from pathlib import Path

DATA_DIR = Path("data")

LOCAL_DATA_FILES = {
    "portfolio": [DATA_DIR / "myPortfolioStocks.csv", Path("myPortfolioStocks.csv")],
    "prospects": [DATA_DIR / "myProspectsScrips.csv", Path("myProspectsScrips.csv")],
    "screener": [DATA_DIR / "myScreenerDB.csv", Path("myScreenerDB.csv")],
    "investments": [DATA_DIR / "myInvestments.csv", Path("myInvestments.csv")],
}

GITHUB_DATA_URLS = {
    "portfolio": "https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/myPortfolioStocks.csv",
    "prospects": "https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/myProspectsScrips.csv",
    "screener": "https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/myScreenerDB.csv",
    "investments": "https://raw.githubusercontent.com/ankit-rathi/Tradevesting_v1/main/data/myInvestments.csv",
}

def _load_data_source(key):
    for local_path in LOCAL_DATA_FILES[key]:
        if local_path.exists():
            df_loaded = pd.read_csv(local_path)
            print(f"Loaded {key} data from local file: {local_path}")
            return df_loaded
    df_loaded = pd.read_csv(GITHUB_DATA_URLS[key])
    print(f"Loaded {key} data from GitHub fallback.")
    return df_loaded

def get_mypfs_df():
    return _load_data_source("portfolio")

def get_mypps_df():
    return _load_data_source("prospects")

def get_myscreen_df():
    return _load_data_source("screener")

def get_myinvmt_df():
    return _load_data_source("investments")

# function to get the stock ids
def get_stock_ids(df_pf):
  stock_n100 = df_pf['Symbol'].unique()

  exclude = ['CADILAHC','MMTC', 'MASFIN']

  stock_ids = df_pf[~df_pf['Symbol'].isin(exclude) ]['Symbol'].unique()

  #mypf = mypf[mypf.Forecast.notnull()]
  #stock_ids = mypf['Symbol'].unique()

  #stock_ids.sort()
  return stock_ids

# get features from screener data
def get_screener_features():
  myscreen_df = get_myscreen_df()
  cols = ['Symbol', 'EPS', 'MedPE', 'ROCE%', 'ROE%', 'CapType']
  return myscreen_df[cols]

# get relative strength
def get_relative_strength(stock_list):

    # Dictionary to store stock tickers and their corresponding percentage price change
    stock_changes = {}

    # Loop through each stock and fetch its price data
    for stock in stock_list:
        try:
            # Download the stock data for the given date range
            stock_data = yfin.Ticker(stock + '.NS').history(period='1mo', interval='1d')[map(str.title, ['open', 'close', 'low', 'high', 'volume'])]

            # Calculate the percentage change for the stock
            if len(stock_data) > 0:
                start_price = stock_data['Close'].iloc[0]
                end_price = stock_data['Close'].iloc[-1]
                percent_change = round(((end_price - start_price) / start_price) * 100, 2)
                stock_changes[stock] = percent_change
            else:
                stock_changes[stock] = np.nan  # If no data is available, set to NaN

        except Exception as e:
            print(f"Error fetching data for {stock}: {e}")
            stock_changes[stock] = np.nan

    # Create a DataFrame with stock tickers and their percentage changes
    df = pd.DataFrame(list(stock_changes.items()), columns=['Symbol', 'Percent_Change'])

    # Drop any stocks with missing data (NaN values)
    df = df.dropna()

    # Calculate the percentile rank based on percentage change
    df['RSP'] = round(df['Percent_Change'].rank(pct=True) * 100, 2)
    cols = ['Symbol', 'RSP']
    df = df[cols]
    # Sort by percentile rank (optional)
    df = df.sort_values(by='RSP', ascending=False).reset_index(drop=True)

    return df

# %%
# function to get stock technicals
def stock_prec_dev(stock_symbol):
    #stock_symbol = 'ULTRACEMCO.NS'
    short_window = 20
    mid_window = 50
    long_window = 200
    moving_avg = 'SMA'

    start = datetime.datetime(*map(int, start_date.split('-')))
    end = datetime.datetime(*map(int, end_date.split('-')))

    stock_df = yfin.Ticker(stock_symbol + '.NS').history(period='max', interval='1d')[map(str.title, ['open', 'close', 'low', 'high', 'volume'])]

    stock_df['Max'] = round(max(stock_df['Close']),2)
    stock_df = stock_df[(stock_df.index <= end_date) & (stock_df.index >= start_date)]
    stock_df['200_SMA'] = round(stock_df['Close'].rolling(window = 200, min_periods = 1).mean(),0)
    stock_df['Dev%_200'] = round((stock_df['Close'] - stock_df['200_SMA'])*100/stock_df['200_SMA'],2)
    stock_df.dropna(axis = 0, inplace = True) # remove any null rows

    stock_df['20_SMA'] = stock_df['Close'].rolling(window=20).mean()
    stock_df['50_SMA'] = stock_df['Close'].rolling(window=50).mean()
    stock_df['Symbol'] = stock_symbol

    stock_df['Close'] = round(stock_df['Close'],2)
    stock_df['Min'] = round(min(stock_df['Close']),2)
    stock_df['RSI_14'] = ta.momentum.RSIIndicator(close=stock_df['Close'], window=14).rsi()
    stock_df['RSI_14'] = round(stock_df['RSI_14'],0)
    stock_df['Prev_Close'] = stock_df['Close'].shift(1)
    stock_df.drop(['Open', 'Low', 'High', 'Volume'], axis=1, inplace=True)
    stock_df = stock_df.tail(1)

    max_SMA = max(stock_df['20_SMA'].item(), stock_df['50_SMA'].item(), stock_df['200_SMA'].item())
    min_SMA = min(stock_df['20_SMA'].item(), stock_df['50_SMA'].item(), stock_df['200_SMA'].item())
    ABS_Spread = max_SMA - min_SMA
    stock_df['Spread%'] = round((ABS_Spread / stock_df['200_SMA'].item()) * 100,2)

    return stock_df

# function to compute stock attributes
def get_common_features(stock_ids, df_mypf):

  df_prec_dev = pd.DataFrame()
  df_tmp = get_screener_features()
  df_rs = get_relative_strength(stock_ids)

  for stock_id in stock_ids:
      tmp = stock_prec_dev(stock_id)
      tmp = tmp.reset_index()
      df_prec_dev = pd.concat([df_prec_dev, tmp], ignore_index = True)
  df_prec_dev = pd.merge(df_prec_dev, df_mypf, on= 'Symbol')
  df_prec_dev = pd.merge(df_prec_dev, df_tmp, on= 'Symbol', how='left')
  df_prec_dev = pd.merge(df_prec_dev, df_rs, on= 'Symbol', how='left')
  #print(df_prec_dev.columns)
  df_prec_dev['Curr_PE'] = round(df_prec_dev['Close']/df_prec_dev['EPS'],1)
  df_prec_dev['Dev%_PE'] = round((df_prec_dev['Curr_PE'] - df_prec_dev['MedPE'])*100/df_prec_dev['MedPE'],2)
  df_prec_dev['Conviction'] = df_prec_dev['Conviction'] + '-' + df_prec_dev['CapType']
  return df_prec_dev

# function to arrange stock features
def arrange_features(df_stocks, common_cols, diff_cols):
  df_stocks_common = df_stocks[common_cols].drop_duplicates()
  df_stocks_diff = df_stocks[diff_cols]
  df_stocks_diff['Investment'] = df_stocks_diff['AvgCost'] * df_stocks_diff['Shares']
  df_stocks_diff = df_stocks_diff.groupby(['Symbol'])[['Shares', 'Investment']].aggregate(['sum']).reset_index()
  df_stocks_diff.columns = ['Symbol', 'Shares', 'Investment']
  df_stocks_diff['AvgCost'] = round(df_stocks_diff['Investment']/df_stocks_diff['Shares'],2)
  df_stocks = pd.merge(df_stocks_diff, df_stocks_common, on='Symbol')
  return df_stocks

# plot fact distribution across dimension
def plot_pie_chart(df, dimension, fact):
  # grouping the data by category and calculating the sum of fact for each type
  grouped_data = df.groupby(dimension)[fact].sum()

  # sorting the grouped data in descending order
  grouped_data = grouped_data.sort_values(ascending=False)

  # creating a pie chart
  grouped_data.plot.pie(autopct='%1.1f%%', startangle=90, figsize=(6, 6))

  # adding a title and displaying the plot
  plt.title(f'{dimension} {fact} Distribution')
  plt.ylabel('')  # To hide the y-label
  plt.show()

# %%
# Portfolio feature engineering + snapshot metrics
def get_portfolio_features(df_common_features):
    print_date_time()
    print('=================== PORTFOLIO QUALITY ====================')

    df_common_features['NTT'] = np.where(
        df_common_features['Strategy'] == 'NTT',
        df_common_features["Target"],
        df_common_features["Max"]
    )
    df_common_features['LTT'] = np.where(
        df_common_features['Strategy'] == 'BTT',
        df_common_features["Target"],
        df_common_features["Max"]
    )
    df_common_features['BOL'] = df_common_features['Min']

    tmp_df = df_common_features[
        df_common_features['Symbol'].isin(
            mypf_df[mypf_df['InPortfolio'] != 'NA'].Symbol.values
        )
    ]
    print('qualified stocks: ' + str(len(tmp_df['Symbol'].unique())))

    tmp_df1 = tmp_df[tmp_df['LatestQtr'] == 1]
    print('with latest results: ' + str(len(tmp_df1['Symbol'].unique())))

    tmp_df1 = tmp_df1[tmp_df1['StarStock'] == 1]
    print('still star stocks: ' + str(len(tmp_df1['Symbol'].unique())))

    tmp_df['Investment'] = tmp_df['AvgCost'] * tmp_df['Shares']
    tmp_df['Current'] = round(tmp_df['Close'] * tmp_df['Shares'], 0)
    tmp_df['Previous'] = tmp_df['Prev_Close'] * tmp_df['Shares']
    tmp_df['EstimatedST'] = tmp_df['NTT'] * tmp_df['Shares']
    tmp_df['EstimatedLT'] = tmp_df['LTT'] * tmp_df['Shares']

    tmp_df['Current P/L'] = round(tmp_df['Current'] - tmp_df['Investment'], 0)
    tmp_df['Today P/L%'] = round(
        (tmp_df['Current'] - tmp_df['Previous']) * 100 / tmp_df['Previous'], 2
    )
    tmp_df['Current P/L%'] = round(
        (tmp_df['Current'] - tmp_df['Investment']) * 100 / tmp_df['Investment'], 2
    )
    tmp_df['EstimatedST P/L%'] = round(
        (tmp_df['EstimatedST'] - tmp_df['Investment']) * 100 / tmp_df['Investment'], 2
    )
    tmp_df['EstimatedLT P/L%'] = round(
        (tmp_df['EstimatedLT'] - tmp_df['Investment']) * 100 / tmp_df['Investment'], 2
    )
    tmp_df['NTT%'] = round(
        (tmp_df['NTT'] - tmp_df['Close']) * 100 / tmp_df['Close'], 2
    )
    tmp_df['LTT%'] = round(
        (tmp_df['LTT'] - tmp_df['Close']) * 100 / tmp_df['Close'], 2
    )
    tmp_df['Gained%'] = round(
        (tmp_df['Close'] - tmp_df['BOL']) * 100 / tmp_df['BOL'], 2
    )

    investment = round(sum(tmp_df['AvgCost'] * tmp_df['Shares']), 0)
    current = round(sum(tmp_df['Close'] * tmp_df['Shares']), 0)

    tmp_df['InitAlloc%'] = round(tmp_df['Investment'] * 100 / investment, 2)
    tmp_df['CurrAlloc%'] = round(tmp_df['Current'] * 100 / current, 2)

    tmp_df['FTT'] = tmp_df['LTT']
    tmp_df.loc[tmp_df['Strategy'] == 'NTT', 'FTT'] = tmp_df['NTT']
    tmp_df['FTT%'] = tmp_df['LTT%']
    tmp_df.loc[tmp_df['Strategy'] == 'NTT', 'FTT%'] = tmp_df['NTT%']
    tmp_df['FTT Amt'] = round(tmp_df['FTT%'] * tmp_df['Current'] / 100, 0)

    tmp_df['OTT%'] = round(
        (tmp_df['FTT'] - tmp_df['AvgCost']) * 100 / tmp_df['AvgCost'], 2
    )
    tmp_df['RRR Ind'] = round(tmp_df['Current P/L'] / tmp_df['FTT Amt'], 2)
    tmp_df['Risk Ind'] = round(tmp_df['Current P/L%'] * tmp_df['CurrAlloc%'], 0)

    return tmp_df


def build_portfolio_snapshot(df_portfolio_features, myinvmt_df):
    """Return the exact portfolio-level metrics used by the original print function."""
    from pyxirr import xirr

    total_booked_amt, reserve_amt, cy_booked_amt, py_booked_amt = get_amt()

    dates = myinvmt_df['Date'].values
    dates = np.append(dates, datetime.date.today().strftime('%d-%b-%y'))
    investment_history = myinvmt_df['Investment'].values
    dates = pd.to_datetime(dates)

    current = round(
        sum(df_portfolio_features['Close'] * df_portfolio_features['Shares']), 0
    ) + reserve_amt

    investment_xirr = np.append(investment_history, current)
    cagr = round(
        xirr(pd.DataFrame({"dates": dates, "amounts": investment_xirr})) * 100, 2
    )

    investment = -sum(investment_history)
    invested = round(
        sum(df_portfolio_features['AvgCost'] * df_portfolio_features['Shares']), 0
    ) + reserve_amt
    previous = round(
        sum(df_portfolio_features['Prev_Close'] * df_portfolio_features['Shares']), 0
    ) + reserve_amt
    cy_invested = investment + py_booked_amt

    today_pnl_amount = current - previous
    today_pnl_percentage = round((current - previous) * 100 / previous, 2)

    curr_pnl_amount = current - invested
    curr_pnl_percentage = round(curr_pnl_amount * 100 / cy_invested, 2)

    cy_pnl_amount = cy_booked_amt + curr_pnl_amount
    cy_pnl_percentage = round(cy_pnl_amount * 100 / cy_invested, 2)

    overall_pnl_amount = total_booked_amt + curr_pnl_amount
    overall_pnl_percentage = round(overall_pnl_amount * 100 / investment, 2)

    estimate_st = round(
        sum(df_portfolio_features['FTT'] * df_portfolio_features['Shares']), 0
    ) + reserve_amt
    est_st_pnl_amount = estimate_st - current
    est_st_pnl_percentage = round(est_st_pnl_amount * 100 / current, 2)

    estimate_lt = round(
        sum(df_portfolio_features['LTT'] * df_portfolio_features['Shares']), 0
    ) + reserve_amt
    est_lt_pnl_amount = estimate_lt - current
    est_lt_pnl_percentage = round(est_lt_pnl_amount * 100 / current, 2)

    total_profit = round(
        sum(df_portfolio_features[df_portfolio_features['Current P/L%'] > 0]['Current'])
        - sum(df_portfolio_features[df_portfolio_features['Current P/L%'] > 0]['Investment']),
        0
    )
    total_loss = round(
        sum(df_portfolio_features[df_portfolio_features['Current P/L%'] < 0]['Current'])
        - sum(df_portfolio_features[df_portfolio_features['Current P/L%'] < 0]['Investment']),
        0
    )

    return {
        "deployed_value": investment,
        "current_value": current,
        "xirr": cagr,
        "est_ftt_value": estimate_st,
        "future_upside_amt": est_st_pnl_amount,
        "future_upside_pct": est_st_pnl_percentage,
        "est_lt_value": estimate_lt,
        "est_lt_upside_amt": est_lt_pnl_amount,
        "est_lt_upside_pct": est_lt_pnl_percentage,
        "current_pnl_amt": curr_pnl_amount,
        "current_pnl_pct": curr_pnl_percentage,
        "total_booked_pnl_amt": total_booked_amt,
        "booked_plus_current_amt": overall_pnl_amount,
        "booked_plus_current_pct": overall_pnl_percentage,
        "cy_booked_pnl_amt": cy_booked_amt,
        "cy_booked_pct": round(cy_booked_amt * 100 / current, 2),
        "prev_year_booked_amt": py_booked_amt,
        "prev_year_booked_pct": round(py_booked_amt * 100 / investment, 2),
        "today_pnl_amt": today_pnl_amount,
        "today_pnl_pct": today_pnl_percentage,
        "cy_invested": cy_invested,
        "reserve": reserve_amt,
        "total_profit": total_profit,
        "total_loss": total_loss,
        "portfolio_count": df_portfolio_features['Symbol'].nunique(),
    }


def print_portfolio_stats(df_portfolio_features, myinvmt_df):
    """Backward-compatible text snapshot; also returns metrics for the UI layer."""
    m = build_portfolio_snapshot(df_portfolio_features, myinvmt_df)

    print('=================== PORTFOLIO SNAPSHOT ===================')
    print('Deployed Value: ', format_amt(m["deployed_value"]))
    print('Current Value:  ', format_amt(m["current_value"]))
    print('CAGR/XIRR %:    ', '{}%'.format(m["xirr"]))
    print('Est FTT Value:  ', format_amt(m["est_ftt_value"]))
    print('Future Upside:  ', '{} ({}%)'.format(
        format_amt(m["future_upside_amt"]), m["future_upside_pct"]
    ))

    print('=================== PERFORMANCE ==========================')
    print('Current PnL:             {} ({}%)'.format(
        format_amt(m["current_pnl_amt"]), m["current_pnl_pct"]
    ))
    print('Total Booked PnL:        {} ({}%)'.format(
        format_amt(m["total_booked_pnl_amt"]),
        round(m["total_booked_pnl_amt"] * 100 / m["deployed_value"], 2)
    ))
    print('Booked + Current PnL:    {} ({}%)'.format(
        format_amt(m["booked_plus_current_amt"]), m["booked_plus_current_pct"]
    ))
    print('CY Booked PnL:           {} ({}%)'.format(
        format_amt(m["cy_booked_pnl_amt"]), m["cy_booked_pct"]
    ))
    print('Prev Year Booked PnL:    {} ({}%)'.format(
        format_amt(m["prev_year_booked_amt"]), m["prev_year_booked_pct"]
    ))

    print('=================== TODAY / OPERATIONS ===================')
    print('Today PnL:               {} ({}%)'.format(
        format_amt(m["today_pnl_amt"]), m["today_pnl_pct"]
    ))
    print('CY Investment:           ', format_amt(m["cy_invested"]))
    print('Reserve:                 ', format_amt(m["reserve"]))

    print('=================== P&L DETAIL ============================')
    print('Total Profit:            ', format_amt(m["total_profit"]))
    print('Total Loss:              ', format_amt(m["total_loss"]))
    print('============================================================')

    return m

# %%
# ============================================================
# 1. DATA LOAD + EXISTING QUANTVESTING CALCULATION ENGINE
# ============================================================
# Data continues to come directly from the existing GitHub repo.
# No portfolio source, calculation, threshold or strategy logic is changed.

start_date, end_date = get_start_end_date()

mypfs_df = get_mypfs_df()
mypps_df = get_mypps_df()
myinvmt_df = get_myinvmt_df()

mypf_df = pd.merge(mypfs_df, mypps_df, on="Symbol")

dm_pf = mypf_df[mypf_df['InPortfolio'] == 'DM']
sv_pf = mypf_df[mypf_df['InPortfolio'] == 'SV']

dm_stocks = get_stock_ids(dm_pf)
sv_stocks = get_stock_ids(sv_pf)
df_stocks = pd.concat([dm_pf, sv_pf], ignore_index=True)

common_cols = [
    'Symbol', 'Target', 'Criteria', 'Strategy', 'CumlRnk',
    'LatestQtr', 'StarStock', 'Conviction', 'Category',
    'InFolio', 'XIRR', 'MBQ'
]
diff_cols = ['Symbol', 'AvgCost', 'Shares']

df_stocks = arrange_features(df_stocks, common_cols, diff_cols)

stock_ids = df_stocks['Symbol'].values
df_common_features = get_common_features(stock_ids, df_stocks)

df_common_features.reset_index(drop=True, inplace=True)
df_common_features.drop(['Date'], axis=1, inplace=True)

df_portfolio_features = get_portfolio_features(df_common_features)
portfolio_snapshot = print_portfolio_stats(df_portfolio_features, myinvmt_df)

df = df_portfolio_features
list_ox40n = list(
    df[df['MBQ'].str.contains('OX40N', na=False)]['Symbol'].values
)

print("\nCalculation engine complete. Launching the intelligence layer below...")
# Out:
# Loaded portfolio data from GitHub fallback.
# Loaded prospects data from GitHub fallback.
# Loaded investments data from GitHub fallback.
# Loaded screener data from GitHub fallback.
# Run date time (IST): 2026-09-02 16:07:14
# =================== PORTFOLIO QUALITY ====================
# qualified stocks: 86
# with latest results: 86
# still star stocks: 46
# =================== PORTFOLIO SNAPSHOT ===================
# Deployed Value:  1.49 C
# Current Value:   1.57 C
# CAGR/XIRR %:     2.36%
# Est FTT Value:   2.75 C
# Future Upside:   1.18 C (74.88%)
# =================== PERFORMANCE ==========================
# Current PnL:             -39.08 L (-20.36%)
# Total Booked PnL:        48.10 L (32.27%)
# Booked + Current PnL:    9.03 L (6.06%)
# CY Booked PnL:           5.24 L (3.33%)
# Prev Year Booked PnL:    42.87 L (28.76%)
# =================== TODAY / OPERATIONS ===================
# Today PnL:               -1.23 L (-0.78%)
# CY Investment:            1.92 C
# Reserve:                  0.00
# =================== P&L DETAIL ============================
# Total Profit:             2.92 L
# Total Loss:               -42.00 L
# ============================================================
#
# Calculation engine complete. Launching the intelligence layer below...

# %% [markdown]
# ---
# # 2. Portfolio Intelligence Terminal
#
# ### **Insight → Evidence → Action**
#
# This presentation layer reorganises the **same existing outputs** into an executive dashboard.
#
# - **Insight:** what deserves attention?
# - **Evidence:** which existing metrics support it?
# - **Action:** what should be reviewed next?
# - **Drill-down:** use the interactive controls to inspect the underlying stocks.
#
# > **Important:** action labels are analytical review prompts derived from the notebook's existing rules. They are not automatic trade instructions.

# %%
# ============================================================
# UI HELPERS — presentation only; no investment logic changed
# ============================================================

DISPLAY_COLS = [
    'Symbol', 'Current', 'CurrAlloc%', 'Current P/L', 'Current P/L%',
    'Today P/L%', 'FTT Amt', 'FTT%', 'RSI_14', 'Dev%_PE',
    'Spread%', 'CumlRnk', 'RRR Ind', 'Gained%', 'Conviction',
    'Criteria', 'Strategy', 'Category'
]

def _available_cols(df, cols=DISPLAY_COLS):
    return [c for c in cols if c in df.columns]

def _money(x):
    try:
        return format_amt(float(x))
    except Exception:
        return str(x)

def _pct(x):
    try:
        return f"{float(x):,.2f}%"
    except Exception:
        return str(x)

def _signed_pct(x):
    try:
        return f"{float(x):+,.2f}%"
    except Exception:
        return str(x)

def _card(title, value, subtitle="", accent=""):
    border = f"border-top:4px solid {accent};" if accent else "border-top:4px solid #5b6472;"
    return f"""
    <div style="
        flex:1; min-width:180px; padding:18px 20px; margin:6px;
        border:1px solid #e5e7eb; border-radius:14px; {border}
        background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
        font-family:Inter,Arial,sans-serif;">
        <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
                    letter-spacing:.08em; font-weight:700;">{title}</div>
        <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">{value}</div>
        <div style="font-size:12px; color:#6b7280;">{subtitle}</div>
    </div>
    """

def _section(title, subtitle=""):
    return HTML(f"""
    <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
        <div style="font-size:22px;font-weight:800;color:#111827;">{title}</div>
        <div style="font-size:13px;color:#6b7280;margin-top:4px;">{subtitle}</div>
    </div>
    """)

def _indian_number(x):
    try:
        x = float(x)
        sign = '-' if x < 0 else ''
        x = abs(round(x))
        s = str(int(x))
        if len(s) <= 3:
            return sign + s
        last3 = s[-3:]
        remaining = s[:-3]
        parts = []
        while len(remaining) > 2:
            parts.insert(0, remaining[-2:])
            remaining = remaining[:-2]
        if remaining:
            parts.insert(0, remaining)
        return sign + ','.join(parts + [last3])
    except Exception:
        return str(x)

def _show_table(df, title=None, max_rows=10):
    if title:
        display(Markdown(f"#### {title}"))
    if df is None or df.empty:
        display(HTML('<div style="padding:14px;border:1px dashed #cbd5e1;border-radius:12px;color:#64748b;">No candidates under the current rule.</div>'))
        return

    view = df.head(max_rows).copy()

    # Table amounts: Indian comma grouping, no decimal places.
    amount_cols = [
        'Current', 'Current P/L', 'FTT Amt', 'Investment',
        'Previous', 'EstimatedST', 'EstimatedLT'
    ]

    for c in amount_cols:
        if c in view.columns:
            view[c] = view[c].map(_indian_number)

    # Percentages: exactly 2 decimal places.
    for c in [c for c in view.columns if '%' in c]:
        view[c] = view[c].map(_pct)

    # Integer metrics: no decimal places.
    for c in ['RSI_14', 'CumlRnk']:
        if c in view.columns:
            view[c] = view[c].map(
                lambda x: f"{float(x):.0f}" if pd.notna(x) else "—"
            )

    # RRR: exactly 2 decimal places.
    if 'RRR Ind' in view.columns:
        view['RRR Ind'] = view['RRR Ind'].map(
            lambda x: f"{float(x):.2f}" if pd.notna(x) else "—"
        )

    cols = _available_cols(view)
    if not cols:
        cols = list(view.columns)
    display(view[cols].style.hide(axis="index"))

def _plotly_layout(fig, title):
    fig.update_layout(
        title=title,
        template="plotly_white",
        margin=dict(l=20,r=20,t=55,b=20),
        height=390,
        font=dict(family="Inter, Arial, sans-serif"),
    )
    return fig

# %%
# ============================================================
# ACTION LIBRARY — preserves the original notebook's insight rules
# ============================================================

def build_action_views(df):
    views = {}

    # Original insight #1 — top 5 near their targets
    tmp = df[~df['Symbol'].isin(['ENRIN','BLUSPRING','DIGITIDE'])].sort_values(
        by='FTT Amt', ascending=True
    )
    views["Near Target"] = tmp.head(5).copy()

    # Original insight #2 — accumulate
    tmp = df[df['Conviction'].isin(['X-LC','H-LC'])]
    tmp = tmp[(tmp['CumlRnk'] < 40) & (tmp['FTT%'] > 20)].sort_values(
        by='CurrAlloc%', ascending=True
    )
    views["Accumulate"] = tmp.head(5).copy()

    # Original insight #3 — today's winners
    views["Today's Winners"] = df.sort_values(by='Today P/L%', ascending=False).head(5).copy()

    # Original insight #4 — today's laggards
    views["Today's Laggards"] = df.sort_values(by='Today P/L%', ascending=True).head(5).copy()

    # Original insight #5 — exit based on cumulative rank
    tmp = df[~df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])]
    tmp = tmp[(tmp['Current P/L%'] > -1) & (tmp['Current P/L%'] < 1)].sort_values(
        by='CumlRnk', ascending=False
    )
    views["Exit Review — Rank"] = tmp.head(5).copy()

    # Original insight #6 — OX40N
    views["OX40N Exit Review"] = df[df['Symbol'].isin(list_ox40n)].sort_values(
        by='Current P/L%', ascending=False
    ).head(5).copy()

    # Original insight #7 — book for rotation
    views["Book for Rotation"] = df[df['Current P/L%'] > 20].sort_values(
        by='CumlRnk', ascending=False
    ).head(5).copy()

    # Original insight #8 — monitor for exit
    tmp = df[~df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])]
    tmp = tmp[tmp['Current P/L%'] > 0].sort_values(by='Dev%_PE', ascending=False)
    views["Monitor Exit"] = tmp.head(5).copy()

    # Original insight #9 — weak conviction rotation
    tmp = df[~df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])]
    tmp = tmp[~tmp['Criteria'].isin(['XY25','XY24','X40','X40N'])].sort_values(
        by='RRR Ind', ascending=False
    )
    views["Weak Conviction Rotation"] = tmp.head(5).copy()

    # Original insight #10 — lowest RSI
    tmp = df[df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])].sort_values(
        by='RSI_14', ascending=True
    )
    views["Accumulate — RSI"] = tmp.head(5).copy()

    # Original insight #11 — spread + rank
    tmp = df[df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])]
    tmp = tmp[tmp['CumlRnk'] < 100].sort_values(by='Spread%', ascending=True)
    views["Accumulate — Spread"] = tmp.head(5).copy()

    # Original insight #12 — lowest gained
    views["Accumulate — Gained"] = df[
        df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])
    ].sort_values(by='Gained%', ascending=True).head(5).copy()

    # Original insight #13 — lowest allocation
    views["Accumulate — Allocation"] = df[
        df['Conviction'].isin(['X-LC','H-LC','X-MC','X-SC'])
    ].sort_values(by='CurrAlloc%', ascending=True).head(5).copy()

    # Original insight #14 — cumulative rank
    views["Best Cumulative Rank"] = df.sort_values(by='CumlRnk', ascending=True).head(5).copy()

    # Original insight #15 — average up
    views["Average Up"] = df[df['Dev%_200'] > 5].sort_values(
        by='CurrAlloc%', ascending=True
    ).head(5).copy()

    # Original insight #16 — relative strength percentile
    views["Relative Strength"] = df.sort_values(by='RSP', ascending=False).head(5).copy()

    return views

ACTION_VIEWS = build_action_views(df_portfolio_features)

ACTION_META = {
    "Near Target": ("Review target proximity", "Prioritise holdings where the existing FTT amount is smallest."),
    "Accumulate": ("Review accumulation candidates", "Existing high-conviction + rank + upside filters are satisfied."),
    "Today's Winners": ("Review today's strength", "Largest positive daily P/L within the current portfolio."),
    "Today's Laggards": ("Review today's weakness", "Largest negative daily P/L within the current portfolio."),
    "Exit Review — Rank": ("Review exit candidates", "Weak conviction + near-flat P/L + weaker cumulative rank."),
    "OX40N Exit Review": ("Review OX40N names", "Existing OX40N portfolio rule is triggered."),
    "Book for Rotation": ("Review profit rotation", "Existing rule flags holdings with >20% current P/L."),
    "Monitor Exit": ("Monitor for exit", "Positive P/L but weaker conviction and elevated PE deviation."),
    "Weak Conviction Rotation": ("Review rotation", "Weak conviction outside the excluded criteria, ranked by RRR."),
    "Accumulate — RSI": ("Review RSI pullbacks", "High-conviction names with the lowest RSI."),
    "Accumulate — Spread": ("Review technical spread", "High-conviction names with lower SMA spread and rank < 100."),
    "Accumulate — Gained": ("Review lower-gained names", "High-conviction names with lower Gained%."),
    "Accumulate — Allocation": ("Review under-allocation", "High-conviction names with the lowest current allocation."),
    "Best Cumulative Rank": ("Review strongest rank", "Lowest cumulative rank in the existing framework."),
    "Average Up": ("Review average-up candidates", "Existing Dev%_200 > 5 filter, prioritised by lower allocation."),
    "Relative Strength": ("Review relative strength", "Highest RSP percentile within the portfolio."),
}

ACTION_VIEW_OPTIONS = list(ACTION_VIEWS.keys())

# %%
# ============================================================
# EXECUTIVE DASHBOARD
# ============================================================

m = portfolio_snapshot
positive = df_portfolio_features[df_portfolio_features['Current P/L%'] > 0]
negative = df_portfolio_features[df_portfolio_features['Current P/L%'] < 0]

top10_alloc = df_portfolio_features.sort_values('CurrAlloc%', ascending=False).head(10)['CurrAlloc%'].sum()

display(HTML(f"""
<div style="padding:24px 28px;border-radius:18px;background:#111827;color:white;
            font-family:Inter,Arial,sans-serif;margin:6px 0 16px;">
    <div style="font-size:12px;letter-spacing:.12em;text-transform:uppercase;
                color:#9ca3af;font-weight:700;">QUANTVESTING / PORTFOLIO TERMINAL</div>
    <div style="font-size:32px;font-weight:850;margin-top:7px;">Portfolio Intelligence</div>
    <div style="font-size:14px;color:#d1d5db;margin-top:6px;">
        {m['portfolio_count']} holdings · {datetime.date.today().strftime('%d %b %Y')}
        · 1-year technical window
    </div>
</div>
"""))

cards = [
    _card("Current Value", _money(m["current_value"]), f"Deployed: {_money(m['deployed_value'])}"),
    _card("Current P/L", f"{_money(m['current_pnl_amt'])}", _pct(m["current_pnl_pct"])),
    _card("XIRR / CAGR", _pct(m["xirr"]), "Portfolio-level return"),
    _card("FTT Upside", _money(m["future_upside_amt"]), _pct(m["future_upside_pct"])),
    _card("Today", _money(m["today_pnl_amt"]), _signed_pct(m["today_pnl_pct"])),
]
display(HTML('<div style="display:flex;flex-wrap:wrap;margin:-6px;">' + ''.join(cards) + '</div>'))

display(_section(
    "Decision radar",
    "The first pass should focus on concentration, current performance, and where the existing framework sees opportunity."
))

radar = pd.DataFrame({
    "Metric": ["Top 10 allocation", "Profitable holdings", "Loss-making holdings", "Reserve"],
    "Value": [
        f"{top10_alloc:.1f}%",
        str(len(positive)),
        str(len(negative)),
        _money(m["reserve"])
    ]
})
display(radar.style.hide(axis="index"))

display(_section(
    "What needs attention now?",
    "These are review queues generated from the notebook's original rules — not new trading logic."
))

attention = pd.DataFrame([
    ["Near Target", "Review holdings closest to the existing target framework.", "FTT Amt"],
    ["Today's Laggards", "Investigate the weakest daily movers.", "Today P/L%"],
    ["Exit Review — Rank", "Review weak-conviction, near-flat positions with lower rank.", "CumlRnk"],
    ["Book for Rotation", "Review profitable holdings already above the existing 20% threshold.", "Current P/L%"],
    ["Accumulate", "Review high-conviction names meeting the existing rank/upside filters.", "CurrAlloc%"],
], columns=["Queue", "Action", "Evidence"])
display(attention.style.hide(axis="index"))

display(_section(
    "Portfolio shape",
    "Allocation concentration and P/L distribution provide the context before stock-level decisions."
))
# Out:
# <div style="padding:24px 28px;border-radius:18px;background:#111827;color:white;
#             font-family:Inter,Arial,sans-serif;margin:6px 0 16px;">
#     <div style="font-size:12px;letter-spacing:.12em;text-transform:uppercase;
#                 color:#9ca3af;font-weight:700;">QUANTVESTING / PORTFOLIO TERMINAL</div>
#     <div style="font-size:32px;font-weight:850;margin-top:7px;">Portfolio Intelligence</div>
#     <div style="font-size:14px;color:#d1d5db;margin-top:6px;">
#         86 holdings · 02 Sep 2026
#         · 1-year technical window
#     </div>
# </div>
# <div style="display:flex;flex-wrap:wrap;margin:-6px;">
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">Current Value</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">1.57 C</div>
#         <div style="font-size:12px; color:#6b7280;">Deployed: 1.49 C</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">Current P/L</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">-39.08 L</div>
#         <div style="font-size:12px; color:#6b7280;">-20.36%</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">XIRR / CAGR</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">2.36%</div>
#         <div style="font-size:12px; color:#6b7280;">Portfolio-level return</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">FTT Upside</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">1.18 C</div>
#         <div style="font-size:12px; color:#6b7280;">74.88%</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">Today</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">-1.23 L</div>
#         <div style="font-size:12px; color:#6b7280;">-0.78%</div>
#     </div>
#     </div>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Decision radar</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">The first pass should focus on concentration, current performance, and where the existing framework sees opportunity.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_a0dbf" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_a0dbf_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a0dbf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0dbf_row0_col0" class="data row0 col0" >Top 10 allocation</td>
#       <td id="T_a0dbf_row0_col1" class="data row0 col1" >21.2%</td>
#     </tr>
#     <tr>
#       <td id="T_a0dbf_row1_col0" class="data row1 col0" >Profitable holdings</td>
#       <td id="T_a0dbf_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <td id="T_a0dbf_row2_col0" class="data row2 col0" >Loss-making holdings</td>
#       <td id="T_a0dbf_row2_col1" class="data row2 col1" >77</td>
#     </tr>
#     <tr>
#       <td id="T_a0dbf_row3_col0" class="data row3 col0" >Reserve</td>
#       <td id="T_a0dbf_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">What needs attention now?</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">These are review queues generated from the notebook's original rules — not new trading logic.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_d3eb4" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_d3eb4_level0_col0" class="col_heading level0 col0" >Queue</th>
#       <th id="T_d3eb4_level0_col1" class="col_heading level0 col1" >Action</th>
#       <th id="T_d3eb4_level0_col2" class="col_heading level0 col2" >Evidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3eb4_row0_col0" class="data row0 col0" >Near Target</td>
#       <td id="T_d3eb4_row0_col1" class="data row0 col1" >Review holdings closest to the existing target framework.</td>
#       <td id="T_d3eb4_row0_col2" class="data row0 col2" >FTT Amt</td>
#     </tr>
#     <tr>
#       <td id="T_d3eb4_row1_col0" class="data row1 col0" >Today's Laggards</td>
#       <td id="T_d3eb4_row1_col1" class="data row1 col1" >Investigate the weakest daily movers.</td>
#       <td id="T_d3eb4_row1_col2" class="data row1 col2" >Today P/L%</td>
#     </tr>
#     <tr>
#       <td id="T_d3eb4_row2_col0" class="data row2 col0" >Exit Review — Rank</td>
#       <td id="T_d3eb4_row2_col1" class="data row2 col1" >Review weak-conviction, near-flat positions with lower rank.</td>
#       <td id="T_d3eb4_row2_col2" class="data row2 col2" >CumlRnk</td>
#     </tr>
#     <tr>
#       <td id="T_d3eb4_row3_col0" class="data row3 col0" >Book for Rotation</td>
#       <td id="T_d3eb4_row3_col1" class="data row3 col1" >Review profitable holdings already above the existing 20% threshold.</td>
#       <td id="T_d3eb4_row3_col2" class="data row3 col2" >Current P/L%</td>
#     </tr>
#     <tr>
#       <td id="T_d3eb4_row4_col0" class="data row4 col0" >Accumulate</td>
#       <td id="T_d3eb4_row4_col1" class="data row4 col1" >Review high-conviction names meeting the existing rank/upside filters.</td>
#       <td id="T_d3eb4_row4_col2" class="data row4 col2" >CurrAlloc%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Portfolio shape</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Allocation concentration and P/L distribution provide the context before stock-level decisions.</div>
#     </div>

# %%
# ============================================================
# VISUAL INSIGHTS
# ============================================================

fig = px.pie(
    df_portfolio_features.groupby('Category', as_index=False)['Current'].sum(),
    names='Category', values='Current', hole=0.55
)
display(_plotly_layout(fig, "Current Value by Sector / Category"))

sector = (
    df_portfolio_features.groupby('Category', as_index=False)
    .agg(Current=('Current','sum'), PnL=('Current P/L','sum'), Allocation=('CurrAlloc%','sum'))
    .sort_values('Current', ascending=False)
)
fig = px.bar(
    sector.head(12).sort_values('Current'),
    x='Current', y='Category', orientation='h',
    hover_data=['PnL','Allocation']
)
display(_plotly_layout(fig, "Largest Portfolio Exposures"))

upside = df_portfolio_features.sort_values('FTT Amt', ascending=False).head(12).sort_values('FTT Amt')
fig = px.bar(
    upside, x='FTT Amt', y='Symbol', orientation='h',
    hover_data=['FTT%','Current P/L%','CurrAlloc%','Conviction']
)
display(_plotly_layout(fig, "Where the Existing Framework Sees the Most FTT Upside"))

daily = df_portfolio_features.sort_values('Today P/L%')
fig = px.bar(
    daily, x='Today P/L%', y='Symbol', orientation='h',
    hover_data=['Current P/L%','CurrAlloc%','Conviction']
)
display(_plotly_layout(fig, "Today's Winners vs Laggards"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="66cb99ac-2780-421d-b93d-5031d57940d8" class="plotly-graph-div" style="height:390px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66cb99ac-2780-421d-b93d-5031d57940d8")) {                    Plotly.newPlot(                        "66cb99ac-2780-421d-b93d-5031d57940d8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.55,"hovertemplate":"Category=%{label}\u003cbr\u003eCurrent=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["AC","APPARELS","AUTO","BANKS","BREWERIES","CABLES","CEMENT","CERAMICS","CHEMICALS","DURABLES","ELECTRICAL","ENGINEERING","ENTERTAINMENT","FINANCE","FMCG","FOOTWEAR","HEALTHCARE","HOTELS","INSURANCE","IT","JEWELLERY","MISC","PAINTS","PHARMA","REFINERIES","TEXTILES","TRAVEL"],"legendgroup":"","name":"","showlegend":true,"values":[269913.0,253400.0,1361771.0,1011997.0,252754.0,222754.0,151992.0,197783.0,187320.0,224792.0,426380.0,188089.0,106600.0,1686689.0,2469540.0,246445.0,104872.0,57235.0,919291.0,1897911.0,142207.0,900676.0,855666.0,966633.0,328275.0,59428.0,212616.0],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ae918b44-ced3-4cf6-8153-42944b3b2ecf" class="plotly-graph-div" style="height:390px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae918b44-ced3-4cf6-8153-42944b3b2ecf")) {                    Plotly.newPlot(                        "ae918b44-ced3-4cf6-8153-42944b3b2ecf",                        [{"alignmentgroup":"True","customdata":[[-49634.0,1.7200000000000002],[-29212.0,2.09],[-94449.0,2.72],[-177341.0,5.45],[-333298.0,5.74],[-70105.0,5.86],[78265.0,6.15],[-124193.0,6.46],[-136258.0,8.67],[-329310.0,10.75],[-667510.0,12.1],[-675353.0,15.719999999999999]],"hovertemplate":"Current=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003ePnL=%{customdata[0]}\u003cbr\u003eAllocation=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[269913.0,328275.0,426380.0,855666.0,900676.0,919291.0,966633.0,1011997.0,1361771.0,1686689.0,1897911.0,2469540.0],"xaxis":"x","y":["AC","REFINERIES","ELECTRICAL","PAINTS","MISC","INSURANCE","PHARMA","BANKS","AUTO","FINANCE","IT","FMCG"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90f633e7-eef8-4686-aac4-fb38f4932e51" class="plotly-graph-div" style="height:390px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90f633e7-eef8-4686-aac4-fb38f4932e51")) {                    Plotly.newPlot(                        "90f633e7-eef8-4686-aac4-fb38f4932e51",                        [{"alignmentgroup":"True","customdata":[[69.73,-24.17,2.11,"X-LC"],[119.26,-26.06,1.29,"X-MC"],[72.98,-17.53,2.11,"X-LC"],[168.51,-43.04,0.98,"H-MC"],[80.18,-29.28,2.2,"X-LC"],[137.17,-18.62,1.3,"M-LC"],[91.85,-23.87,2.17,"X-LC"],[208.38,-43.31,0.97,"X-SC"],[147.65,-22.3,1.38,"H-SC"],[144.72,-22.43,1.42,null],[153.59,-34.14,1.49,"X-SC"],[264.18,-40.35,1.03,null]],"hovertemplate":"FTT Amt=%{x}\u003cbr\u003eSymbol=%{y}\u003cbr\u003eFTT%=%{customdata[0]}\u003cbr\u003eCurrent P\u002fL%=%{customdata[1]}\u003cbr\u003eCurrAlloc%=%{customdata[2]}\u003cbr\u003eConviction=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[231371.0,240786.0,241272.0,259620.0,276746.0,279352.0,312827.0,316721.0,319569.0,321616.0,360420.0,426709.0],"xaxis":"x","y":["ITC","BAJAJHFL","INFY","IRCTC","TCS","WIPRO","TMPV","ACC","BANDHANBNK","REPCOHOME","AWL","TANLA"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="002ed8d9-706e-4ec9-99a9-d26cf0b43e5b" class="plotly-graph-div" style="height:390px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("002ed8d9-706e-4ec9-99a9-d26cf0b43e5b")) {                    Plotly.newPlot(                        "002ed8d9-706e-4ec9-99a9-d26cf0b43e5b",                        [{"alignmentgroup":"True","customdata":[[50.87,1.42,"M-SC"],[-9.87,1.1,"X-MC"],[-55.14,0.41,null],[-9.84,0.56,"H-SC"],[-40.35,1.03,null],[-18.62,1.3,"M-LC"],[-23.62,1.6,"X-MC"],[-35.92,0.89,"H-SC"],[-55.7,0.36,null],[-0.4,1.91,"X-LC"],[-19.56,1.01,null],[-18.58,1.04,"X-MC"],[-0.68,1.98,"X-LC"],[-8.38,1.93,"X-LC"],[-43.04,0.98,"H-MC"],[-15.86,0.54,null],[-33.72,0.77,null],[-34.14,1.49,"X-SC"],[-52.52,0.31,null],[-12.03,2.03,"X-LC"],[18.42,1.5,"X-MC"],[-42.94,0.4,null],[-41.83,0.79,"X-SC"],[-42.11,0.67,null],[-8.89,2.09,"X-LC"],[-27.8,0.36,"L-MC"],[-17.53,2.11,"X-LC"],[-25.09,0.8,null],[-2.8,1.56,"X-SC"],[-7.67,1.83,"X-LC"],[-25.19,0.59,null],[-57.88,0.49,null],[-25.9,1.17,"X-MC"],[11.44,1.78,"X-LC"],[21.71,1.62,"H-LC"],[-56.54,0.47,null],[-8.81,1.12,"X-SC"],[-22.33,1.2,null],[-56.75,0.35,null],[-13.2,1.4,"X-SC"],[-16.12,2.01,"X-LC"],[-25.96,0.83,null],[-29.28,2.2,"X-LC"],[-22.43,1.42,null],[-22.3,1.38,"H-SC"],[-48.48,0.43,null],[-47.99,0.44,"H-SC"],[-6.12,1.8,"X-LC"],[6.2,2.03,"X-LC"],[-24.03,0.62,"M-SC"],[-10.06,1.48,"X-MC"],[-46.63,0.48,null],[-62.07,0.32,null],[-43.31,0.97,"X-SC"],[11.31,1.7,"X-LC"],[-12.63,1.0,"X-MC"],[-35.58,0.38,"M-SC"],[-19.33,1.03,null],[-3.36,1.37,"M-SC"],[-6.33,2.11,"X-LC"],[-16.82,0.92,"M-SC"],[-35.87,0.47,null],[-24.17,2.11,"X-LC"],[-26.06,1.29,"X-MC"],[7.95,1.61,"X-MC"],[-17.67,1.31,"X-MC"],[-34.98,1.12,"H-SC"],[-29.32,1.19,"X-MC"],[-66.89,0.37,null],[-47.24,0.28,null],[-8.17,2.09,"X-LC"],[-36.36,1.06,null],[-16.7,2.13,"X-LC"],[8.94,1.95,"H-SC"],[-13.53,0.99,"H-SC"],[-1.24,0.7,"H-SC"],[-14.33,1.11,"M-MC"],[-17.34,1.04,"X-MC"],[-23.87,2.17,"X-LC"],[6.29,1.77,"X-MC"],[-23.79,0.49,"M-SC"],[-5.58,1.61,"X-MC"],[-14.39,2.14,"X-LC"],[-49.59,0.36,null],[-84.64,0.13,null],[-37.43,0.65,null]],"hovertemplate":"Today P\u002fL%=%{x}\u003cbr\u003eSymbol=%{y}\u003cbr\u003eCurrent P\u002fL%=%{customdata[0]}\u003cbr\u003eCurrAlloc%=%{customdata[1]}\u003cbr\u003eConviction=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[-4.57,-4.39,-3.6,-3.3,-2.82,-2.54,-2.44,-2.41,-2.16,-2.12,-2.03,-1.91,-1.86,-1.86,-1.82,-1.77,-1.68,-1.61,-1.58,-1.56,-1.54,-1.52,-1.51,-1.51,-1.47,-1.47,-1.38,-1.36,-1.35,-1.35,-1.34,-1.31,-1.3,-1.17,-1.16,-1.16,-1.15,-1.08,-1.02,-0.99,-0.99,-0.96,-0.89,-0.88,-0.85,-0.83,-0.8,-0.78,-0.72,-0.66,-0.57,-0.47,-0.45,-0.45,-0.35,-0.34,-0.33,-0.29,-0.28,-0.28,-0.12,-0.12,-0.11,-0.08,-0.03,0.0,0.04,0.09,0.17,0.29,0.31,0.33,0.45,0.46,0.5,0.57,0.76,0.82,0.89,0.89,1.12,1.47,2.25,2.51,4.99,4.99],"xaxis":"x","y":["FINCABLES","VOLTAS","RELAXO","MASFIN","TANLA","WIPRO","HAVELLS","5PAISA","HAPPSTMNDS","M&M","ATULAUTO","ICICIGI","BAJAJHLDNG","ASIANPAINT","IRCTC","ALKYLAMINE","VAIBHAVGBL","AWL","RAJOOENG","HDFCBANK","GLAXO","HATHWAY","PGHH","SHALBY","HCLTECH","INDUSINDBK","INFY","CAMPUS","CAMS","HDFCLIFE","INDIAMART","GREENPANEL","DABUR","HYUNDAI","ZYDUSLIFE","SYMPHONY","HONAUT","TITAGARH","BATAINDIA","GILLETTE","HINDUNILVR","CERA","TCS","REPCOHOME","BANDHANBNK","LAOPALA","TATAELXSI","MARUTI","CIPLA","BOSCH-HCIL","BERGEPAINT","BSOFT","ROUTE","ACC","KOTAKBANK","ABBOTINDIA","TRIDENT","IEX","UTIAMC","DMART","INDIGOPNTS","WHIRLPOOL","ITC","BAJAJHFL","UNITDSPR","GODREJCP","KANSAINER","COLPAL","EASEMYTRIP","DEN","RELIANCE","SFL","JIOFIN","STARHEALTH","SURYODAY","SIS","RECLTD","ICICIPRULI","TMPV","DIXON", ...

# %% [markdown]
# ---
# # 3. Holding Quality Assessment
#
# ### **Portfolio → Prospects → Screener → Conviction**
#
# The user's `myPortfolioStocks.csv` is treated as the portfolio input. Every holding is retained and assessed against the existing Prospects universe, then enriched with available Screener data.
#
# **Classification**
#
# - **X — Exceptional:** Prospects conviction = X
# - **H — High Quality:** Prospects conviction = H
# - **M — Medium:** Prospects conviction = M
# - **L — Low:** Prospects conviction = L, or the holding is not in Prospects
# - **LC / MC / SC:** Screener `CapType` first; Prospects `CapType` as fallback
#
# Unlike the original calculation engine, this assessment deliberately **does not drop holdings that are absent from Prospects**.
#
# > This is an analytical classification/reporting framework based on the supplied datasets, not an automatic trading instruction.

# %%
# ============================================================
# HOLDING QUALITY ASSESSMENT ENGINE
# ============================================================

CONVICTION_ORDER = ["X", "H", "M", "L"]
CONVICTION_SCORE = {"X": 100, "H": 80, "M": 60, "L": 40}

def _normalise_symbols(df):
    out = df.copy()
    if "Symbol" not in out.columns:
        raise ValueError("The input file must contain a 'Symbol' column.")
    out["Symbol"] = (
        out["Symbol"].astype(str).str.strip().str.upper()
        .str.replace(".NS", "", regex=False)
    )
    return out

def _clean_conviction(value):
    if pd.isna(value):
        return np.nan
    value = str(value).strip().upper()
    return value.split("-")[0] if value else np.nan

def _clean_cap(value):
    if pd.isna(value):
        return np.nan
    value = str(value).strip().upper()
    for cap in ["LC", "MC", "SC"]:
        if cap in value:
            return cap
    return value if value else np.nan

def _first_existing(df, candidates):
    for c in candidates:
        if c in df.columns:
            return c
    return None

def build_holding_assessment(portfolio_df, prospects_df, screener_df):
    pf = _normalise_symbols(portfolio_df)
    pp = _normalise_symbols(prospects_df)
    sc = _normalise_symbols(screener_df)

    if "InPortfolio" in pf.columns:
        active = pf[pf["InPortfolio"].astype(str).str.upper().ne("NA")].copy()
        if active.empty:
            active = pf.copy()
    else:
        active = pf.copy()

    if "Shares" not in active.columns:
        raise ValueError("The portfolio file must contain a 'Shares' column.")

    active["Shares"] = pd.to_numeric(active["Shares"], errors="coerce").fillna(0)

    if "AvgCost" in active.columns:
        active["AvgCost"] = pd.to_numeric(active["AvgCost"], errors="coerce")
        active["Investment"] = active["Shares"] * active["AvgCost"]
    else:
        active["AvgCost"] = np.nan
        active["Investment"] = np.nan

    holding = (
        active.groupby("Symbol", as_index=False)
        .agg(Shares=("Shares", "sum"), Investment=("Investment", "sum"))
    )
    holding["AvgCost"] = np.where(
        holding["Shares"] != 0,
        holding["Investment"] / holding["Shares"],
        np.nan
    )

    meta_cols = [
        "InPortfolio", "Account", "Broker", "Category",
        "Strategy", "InFolio"
    ]
    meta_cols = [c for c in meta_cols if c in active.columns]
    if meta_cols:
        meta = active[["Symbol"] + meta_cols].drop_duplicates("Symbol")
        holding = holding.merge(meta, on="Symbol", how="left")

    prospect_unique = pp.drop_duplicates("Symbol")
    screener_unique = sc.drop_duplicates("Symbol")

    prospect_payload = [c for c in prospect_unique.columns if c != "Symbol"]
    screener_payload = [c for c in screener_unique.columns if c != "Symbol"]

    assessment = holding.merge(
        prospect_unique[["Symbol"] + prospect_payload],
        on="Symbol", how="left", suffixes=("", "_Prospect")
    )
    assessment = assessment.merge(
        screener_unique[["Symbol"] + screener_payload],
        on="Symbol", how="left", suffixes=("", "_Screener")
    )

    prospect_symbols = set(prospect_unique["Symbol"])
    assessment["Prospect Status"] = np.where(
        assessment["Symbol"].isin(prospect_symbols), "Yes", "No"
    )

    if "Conviction" in assessment.columns:
        conviction_col = "Conviction"
    elif "Conviction_Prospect" in assessment.columns:
        conviction_col = "Conviction_Prospect"
    else:
        conviction_col = None

    if conviction_col:
        assessment["Conviction"] = assessment[conviction_col].map(_clean_conviction)
    else:
        assessment["Conviction"] = np.nan

    assessment.loc[assessment["Prospect Status"].eq("No"), "Conviction"] = "L"

    valid = assessment["Conviction"].isin(CONVICTION_ORDER)
    assessment.loc[~valid, "Conviction"] = "L"

    assessment["Assessment Basis"] = np.where(
        assessment["Prospect Status"].eq("No"),
        "Not in Prospects",
        assessment["Conviction"].map(
            lambda x: f"Prospects: {x}" if pd.notna(x)
            else "Prospects: conviction unavailable"
        )
    )

    # Market cap comes from Screener first, Prospects second.
    screener_cap_col = (
        "CapType" if "CapType" in assessment.columns
        else "CapType_Screener" if "CapType_Screener" in assessment.columns
        else None
    )
    prospect_cap_col = (
        "CapType_Prospect" if "CapType_Prospect" in assessment.columns
        else None
    )

    if screener_cap_col:
        cap = assessment[screener_cap_col].map(_clean_cap)
    else:
        cap = pd.Series(np.nan, index=assessment.index)

    if prospect_cap_col:
        cap = cap.fillna(assessment[prospect_cap_col].map(_clean_cap))

    assessment["CapType"] = cap
    assessment["Conviction-Cap"] = (
        assessment["Conviction"].fillna("L") + "-"
        + assessment["CapType"].fillna("NA")
    )
    assessment["Assessment Score"] = assessment["Conviction"].map(CONVICTION_SCORE)

    # Optional valuation evidence if the required Screener fields exist.
    eps_col = _first_existing(assessment, ["EPS", "EPS_Screener"])
    medpe_col = _first_existing(assessment, ["MedPE", "MedPE_Screener"])
    price_col = _first_existing(
        assessment,
        ["Close", "CMP", "Current Price", "CurrentPrice", "Price", "LTP"]
    )

    if eps_col and medpe_col and price_col:
        eps = pd.to_numeric(assessment[eps_col], errors="coerce")
        medpe = pd.to_numeric(assessment[medpe_col], errors="coerce")
        price = pd.to_numeric(assessment[price_col], errors="coerce")
        assessment["Curr_PE"] = np.where(eps > 0, price / eps, np.nan)
        assessment["Dev%_PE"] = np.where(
            medpe != 0,
            (assessment["Curr_PE"] - medpe) * 100 / medpe,
            np.nan
        )

    if price_col:
        price = pd.to_numeric(assessment[price_col], errors="coerce")
        assessment["Current"] = price * assessment["Shares"]

    rank_map = {"X": 0, "H": 1, "M": 2, "L": 3}
    assessment["_conv_rank"] = assessment["Conviction"].map(rank_map).fillna(9)
    assessment = assessment.sort_values(
        ["_conv_rank", "Investment"], ascending=[True, False]
    ).drop(columns="_conv_rank")

    return assessment.reset_index(drop=True)

df_holding_assessment = build_holding_assessment(
    mypfs_df,
    mypps_df,
    get_myscreen_df()
)

print(f"User holdings assessed: {len(df_holding_assessment)}")
print(f"Prospect holdings: {(df_holding_assessment['Prospect Status'] == 'Yes').sum()}")
print(f"Non-prospect holdings: {(df_holding_assessment['Prospect Status'] == 'No').sum()}")
# Out:
# Loaded screener data from GitHub fallback.
# User holdings assessed: 86
# Prospect holdings: 86
# Non-prospect holdings: 0

# %%
# ============================================================
# PORTFOLIO ASSESSMENT TERMINAL
# ============================================================

assessment_df = df_holding_assessment.copy()

def _assessment_amount(x):
    return _indian_number(x) if pd.notna(x) else "—"

counts = assessment_df["Conviction"].value_counts()
prospect_count = int((assessment_df["Prospect Status"] == "Yes").sum())
nonprospect_count = int((assessment_df["Prospect Status"] == "No").sum())
total_holdings = len(assessment_df)

display(_section(
    "Portfolio Quality Snapshot",
    "Every holding is retained, classified and enriched with available Screener evidence."
))

cards = [
    _card("Holdings", str(total_holdings), "User portfolio"),
    _card("X — Exceptional", str(int(counts.get("X", 0))), "Prospect conviction"),
    _card("H — High", str(int(counts.get("H", 0))), "Prospect conviction"),
    _card("M — Medium", str(int(counts.get("M", 0))), "Prospect conviction"),
    _card("L — Low", str(int(counts.get("L", 0))), f"{nonprospect_count} not in Prospects"),
]
display(HTML('<div style="display:flex;flex-wrap:wrap;margin:-6px;">' + ''.join(cards) + '</div>'))

coverage = round(prospect_count * 100 / total_holdings, 2) if total_holdings else 0
coverage_df = pd.DataFrame({
    "Metric": ["Prospect Coverage", "Not in Prospects", "Prospect Holdings"],
    "Value": [f"{coverage:.2f}%", str(nonprospect_count), str(prospect_count)]
})
display(coverage_df.style.hide(axis="index"))

matrix = pd.crosstab(
    assessment_df["Conviction"],
    assessment_df["CapType"]
).reindex(index=["X", "H", "M", "L"], columns=["LC", "MC", "SC"], fill_value=0)

display(_section(
    "Conviction × Market Cap",
    "X/H/M/L and LC/MC/SC are maintained as separate dimensions."
))
display(matrix)

display(_section(
    "Holding Assessment",
    "Prospects determines conviction; Screener provides market-cap and supporting evidence."
))

preferred_cols = [
    "Symbol", "Shares", "Investment", "Current",
    "Prospect Status", "Conviction", "CapType", "Conviction-Cap",
    "Assessment Score", "Assessment Basis",
    "Criteria", "CumlRnk", "EPS", "MedPE", "ROCE%", "ROE%",
    "Curr_PE", "Dev%_PE"
]
preferred_cols = [c for c in preferred_cols if c in assessment_df.columns]
table = assessment_df[preferred_cols].copy()

for c in ["Investment", "Current"]:
    if c in table.columns:
        table[c] = table[c].map(_assessment_amount)

for c in ["ROCE%", "ROE%", "Dev%_PE"]:
    if c in table.columns:
        table[c] = table[c].map(_pct)

if "CumlRnk" in table.columns:
    table["CumlRnk"] = table["CumlRnk"].map(
        lambda x: f"{float(x):.0f}" if pd.notna(x) else "—"
    )

for c in ["EPS", "MedPE", "Curr_PE"]:
    if c in table.columns:
        table[c] = table[c].map(
            lambda x: f"{float(x):.2f}" if pd.notna(x) else "—"
        )

display(table.style.hide(axis="index"))

low_df = assessment_df[assessment_df["Conviction"].eq("L")].copy()

display(_section(
    "L — Low Conviction Review",
    "Non-prospect holdings are deliberately retained and explicitly identified."
))

low_cols = [
    "Symbol", "Shares", "Investment", "Prospect Status",
    "Conviction", "CapType", "Assessment Basis",
    "Criteria", "CumlRnk", "EPS", "MedPE", "ROCE%", "ROE%"
]
low_cols = [c for c in low_cols if c in low_df.columns]
low_view = low_df[low_cols].copy()

if "Investment" in low_view.columns:
    low_view["Investment"] = low_view["Investment"].map(_assessment_amount)

for c in ["ROCE%", "ROE%"]:
    if c in low_view.columns:
        low_view[c] = low_view[c].map(_pct)

if "CumlRnk" in low_view.columns:
    low_view["CumlRnk"] = low_view["CumlRnk"].map(
        lambda x: f"{float(x):.0f}" if pd.notna(x) else "—"
    )

display(low_view.style.hide(axis="index"))

display(_section(
    "Why is this holding X / H / M / L?",
    "Select a holding to inspect its classification basis and available evidence."
))

assessment_selector = widgets.Dropdown(
    options=sorted(assessment_df["Symbol"].dropna().unique().tolist()),
    description="Holding:",
    layout=widgets.Layout(width="420px"),
    style={"description_width": "75px"}
)
assessment_output = widgets.Output()

def render_assessment(change=None):
    with assessment_output:
        clear_output(wait=True)
        symbol = assessment_selector.value
        row = assessment_df[assessment_df["Symbol"] == symbol].iloc[0]

        conv = row.get("Conviction", "L")
        cap = row.get("CapType", "NA")
        status = row.get("Prospect Status", "No")
        basis = row.get("Assessment Basis", "")

        display(HTML(f'''
        <div style="padding:18px 20px;border-radius:14px;background:#f8fafc;
                    border:1px solid #e2e8f0;font-family:Inter,Arial,sans-serif;">
            <div style="font-size:13px;color:#64748b;text-transform:uppercase;
                        letter-spacing:.08em;font-weight:700;">Assessment</div>
            <div style="font-size:28px;font-weight:850;color:#111827;margin-top:5px;">
                {symbol} · {conv}-{cap}
            </div>
            <div style="font-size:13px;color:#475569;margin-top:8px;">
                Prospect: <b>{status}</b> · {basis}
            </div>
        </div>
        '''))

        evidence = {
            "Symbol": symbol,
            "Prospect Status": status,
            "Conviction": conv,
            "CapType": cap,
            "Assessment Score": row.get("Assessment Score", np.nan),
            "Assessment Basis": basis,
        }

        for c in [
            "Criteria", "CumlRnk", "EPS", "MedPE", "ROCE%", "ROE%",
            "Curr_PE", "Dev%_PE", "Category", "Strategy"
        ]:
            if c in row.index:
                evidence[c] = row[c]

        ev = pd.DataFrame.from_dict(evidence, orient="index", columns=["Value"])

        if "CumlRnk" in ev.index:
            try:
                ev.loc["CumlRnk", "Value"] = f"{float(ev.loc['CumlRnk', 'Value']):.0f}"
            except Exception:
                pass

        for c in ["ROCE%", "ROE%", "Dev%_PE"]:
            if c in ev.index:
                try:
                    ev.loc[c, "Value"] = f"{float(ev.loc[c, 'Value']):.2f}%"
                except Exception:
                    pass

        for c in ["EPS", "MedPE", "Curr_PE"]:
            if c in ev.index:
                try:
                    ev.loc[c, "Value"] = f"{float(ev.loc[c, 'Value']):.2f}"
                except Exception:
                    pass

        display(ev)

assessment_selector.observe(render_assessment, names="value")
display(assessment_selector)
display(assessment_output)
render_assessment()
# Out:
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Portfolio Quality Snapshot</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Every holding is retained, classified and enriched with available Screener evidence.</div>
#     </div>
# <div style="display:flex;flex-wrap:wrap;margin:-6px;">
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">Holdings</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">86</div>
#         <div style="font-size:12px; color:#6b7280;">User portfolio</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">X — Exceptional</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">41</div>
#         <div style="font-size:12px; color:#6b7280;">Prospect conviction</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">H — High</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">25</div>
#         <div style="font-size:12px; color:#6b7280;">Prospect conviction</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">M — Medium</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">17</div>
#         <div style="font-size:12px; color:#6b7280;">Prospect conviction</div>
#     </div>
#
#     <div style="
#         flex:1; min-width:180px; padding:18px 20px; margin:6px;
#         border:1px solid #e5e7eb; border-radius:14px; border-top:4px solid #5b6472;
#         background:#ffffff; box-shadow:0 2px 10px rgba(0,0,0,.05);
#         font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:12px; color:#6b7280; text-transform:uppercase;
#                     letter-spacing:.08em; font-weight:700;">L — Low</div>
#         <div style="font-size:26px; font-weight:800; margin:8px 0 4px;">3</div>
#         <div style="font-size:12px; color:#6b7280;">0 not in Prospects</div>
#     </div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_8cd92" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8cd92_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_8cd92_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8cd92_row0_col0" class="data row0 col0" >Prospect Coverage</td>
#       <td id="T_8cd92_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <td id="T_8cd92_row1_col0" class="data row1 col0" >Not in Prospects</td>
#       <td id="T_8cd92_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_8cd92_row2_col0" class="data row2 col0" >Prospect Holdings</td>
#       <td id="T_8cd92_row2_col1" class="data row2 col1" >86</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Conviction × Market Cap</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">X/H/M/L and LC/MC/SC are maintained as separate dimensions.</div>
#     </div>
# CapType     LC  MC  SC
# Conviction
# X           19  14   6
# H            1   1   8
# M            1   1   6
# L            0   1   0
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Holding Assessment</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Prospects determines conviction; Screener provides market-cap and supporting evidence.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_5e347" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_5e347_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_5e347_level0_col1" class="col_heading level0 col1" >Shares</th>
#       <th id="T_5e347_level0_col2" class="col_heading level0 col2" >Investment</th>
#       <th id="T_5e347_level0_col3" class="col_heading level0 col3" >Current</th>
#       <th id="T_5e347_level0_col4" class="col_heading level0 col4" >Prospect Status</th>
#       <th id="T_5e347_level0_col5" class="col_heading level0 col5" >Conviction</th>
#       <th id="T_5e347_level0_col6" class="col_heading level0 col6" >CapType</th>
#       <th id="T_5e347_level0_col7" class="col_heading level0 col7" >Conviction-Cap</th>
#       <th id="T_5e347_level0_col8" class="col_heading level0 col8" >Assessment Score</th>
#       <th id="T_5e347_level0_col9" class="col_heading level0 col9" >Assessment Basis</th>
#       <th id="T_5e347_level0_col10" class="col_heading level0 col10" >Criteria</th>
#       <th id="T_5e347_level0_col11" class="col_heading level0 col11" >CumlRnk</th>
#       <th id="T_5e347_level0_col12" class="col_heading level0 col12" >EPS</th>
#       <th id="T_5e347_level0_col13" class="col_heading level0 col13" >MedPE</th>
#       <th id="T_5e347_level0_col14" class="col_heading level0 col14" >ROCE%</th>
#       <th id="T_5e347_level0_col15" class="col_heading level0 col15" >ROE%</th>
#       <th id="T_5e347_level0_col16" class="col_heading level0 col16" >Curr_PE</th>
#       <th id="T_5e347_level0_col17" class="col_heading level0 col17" >Dev%_PE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e347_row0_col0" class="data row0 col0" >TCS</td>
#       <td id="T_5e347_row0_col1" class="data row0 col1" >147</td>
#       <td id="T_5e347_row0_col2" class="data row0 col2" >4,88,075</td>
#       <td id="T_5e347_row0_col3" class="data row0 col3" >3,44,766</td>
#       <td id="T_5e347_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_5e347_row0_col5" class="data row0 col5" >X</td>
#       <td id="T_5e347_row0_col6" class="data row0 col6" >LC</td>
#       <td id="T_5e347_row0_col7" class="data row0 col7" >X-LC</td>
#       <td id="T_5e347_row0_col8" class="data row0 col8" >100</td>
#       <td id="T_5e347_row0_col9" class="data row0 col9" >Prospects: X</td>
#       <td id="T_5e347_row0_col10" class="data row0 col10" >X40</td>
#       <td id="T_5e347_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_5e347_row0_col12" class="data row0 col12" >137.64</td>
#       <td id="T_5e347_row0_col13" class="data row0 col13" >29.81</td>
#       <td id="T_5e347_row0_col14" class="data row0 col14" >63.03%</td>
#       <td id="T_5e347_row0_col15" class="data row0 col15" >51.81%</td>
#       <td id="T_5e347_row0_col16" class="data row0 col16" >17.04</td>
#       <td id="T_5e347_row0_col17" class="data row0 col17" >-42.84%</td>
#     </tr>
#     <tr>
#       <td id="T_5e347_row1_col0" class="data row1 col0" >TMPV</td>
#       <td id="T_5e347_row1_col1" class="data row1 col1" >1089</td>
#       <td id="T_5e347_row1_col2" class="data row1 col2" >4,47,372</td>
#       <td id="T_5e347_row1_col3" class="data row1 col3" >3,78,373</td>
#       <td id="T_5e347_row1_col4" class="data row1 col4" >Yes</td>
#       <td id="T_5e347_row1_col5" class="data row1 col5" >X</td>
#       <td id="T_5e347_row1_col6" class="data row1 col6" >LC</td>
#       <td id="T_5e347_row1_col7" class="data row1 col7" >X-LC</td>
#       <td id="T_5e347_row1_col8" class="data row1 col8" >100</td>
#       <td id="T_5e347_row1_col9" class="data row1 col9" >Prospects: X</td>
#       <td id="T_5e347_row1_col10" class="data row1 col10" >XY24</td>
#       <td id="T_5e347_row1_col11" class="data row1 col11" >4</td>
#       <td id="T_5e347_row1_col12" class="data row1 col12" >223.74</td>
#       <td id="T_5e347_row1_col13" class="data row1 col13" >9.28</td>
#       <td id="T_5e347_row1_col14" class="data row1 col14" >2.73%</td>
#       <td id="T_5e347_row1_col15" class="data row1 col15" >75.66%</td>
#       <td id="T_5e347_row1_col16" class="data row1 col16" >1.55</td>
#       <td id="T_5e347_row1_col17" class="data row1 col17" >-83.27%</td>
#     </tr>
#     <tr>
#       <td id="T_5e347_row2_col0" class="data row2 col0" >ITC</td>
#       <td id="T_5e347_row2_col1" class="data row2 col1" >1246</td>
#       <td id="T_5e347_row2_col2" class="data row2 col2" >4,37,595</td>
#       <td id="T_5e347_row2_col3" class="data row2 col3" >3,44,706</td>
#       <td id="T_5e347_row2_col4" class="data row2 col4" >Yes</td>
#       <td id="T_5e347_row2_col5" class="data row2 col5" >X</td>
#       <td id="T_5e347_row2_col6" class="data row2 col6" >LC</td>
#       <td id="T_5e347_row2_col7" class="data row2 col7" >X-LC</td>
#       <td id="T_5e347_row2_col8" class="data row2 col8" >100</td>
#       <td id="T_5e347_row2_col9" class="data row2 col9" >Prospects: X</td>
#       <td id="T_5e347_row2_col10" class="data row2 col10" >X40</td>
#       <td id="T_5e347_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_5e347_row2_col12" class="data row2 col12" >15.84</td>
#       <td id="T_5e347_row2_col13" class="data row2 col13" >24.55</td>
#       <td id="T_5e347_row2_col14" class="data row2 col14" >38.91%</td>
#       <td id="T_5e347_row2_col15" class="data row2 col15" >29.32%</td>
#       <td id="T_5e347_row2_col16" class="data row2 col16" >17.47</td>
#       <td id="T_5e347_row2_col17" class="data row2 col17" >-28.86%</td>
#     </tr>
#     <tr>
#       <td id="T_5e347_row3_col0" class="data row3 col0" >JIOFIN</td>
#       <td id="T_5e347_row3_col1" class="data row3 col1" >1412</td>
#       <td id="T_5e347_row3_col2" class="data row3 col2" >4,01,545</td>
#       <td id="T_5e347_row3_col3" class="data row3 col3" >3,63,449</td>
#       <td id="T_5e347_row3_col4" class="data row3 col4" >Yes</td>
#       <td id="T_5e347_row3_col5" class="data row3 col5" >X</td>
#       <td id="T_5e347_row3_col6" class="data row3 col6" >LC</td>
#       <td id="T_5e347_row3_col7" class="data row3 col7" >X-LC</td>
#       <td id="T_5e347_row3_col8" class="data row3 col8" >100</td>
#       <td id="T_5e347_row3_col9" class="data row3 col9" >Prospects: X</td>
#       <td id="T_5e347_row3_col10" class="data row3 col10" >XY24</td>
#       <td id="T_5e347_row3_col11" class="data row3 col11" >34</td>
#       <td id="T_5e347_row3_col12" class="data row3 col12" >3.20</td>
#       <td id="T_5e347_row3_col13" class="data row3 col13" >115.96</td>
#       <td id="T_5e347_row3_col14" class="data row3 col14" >1.86%</td>
#       <td id="T_5e347_row3_col15" class="data row3 col15" >1.19%</td>
#       <td id="T_5e347_row3_col16" class="data row3 col16" >80.44</td>
#       <td id="T_5e347_row3_col17" class="data row3 col17" >-30.63%</td>
#     </tr>
#     <tr>
#       <td id="T_5e347_row4_col0" class="data row4 col0" >INFY</td>
#       <td id="T_5e347_row4_col1" class="data row4 col1" >290</td>
#       <td id="T_5e347_row4_col2" class="data row4 col2" >4,00,855</td>
#       <td id="T_5e347_row4_col3" class="data row4 col3" >3,36,298</td>
#       <td id="T_5e347_row4_col4" class="data row4 col4" >Yes</td>
#       <td id="T_5e347_row4_col5" class="data row4 col5" >X</td>
#       <td id="T_5e347_row4_col6" class="data row4 col6" >LC</td>
#       <td id="T_5e347_row4_col7" class="data row4 col7" >X-LC</td>
#       <td id="T_5e347_row4_col8" class="data row4 col8" >100</td>
#       <td id="T_5e347_row4_col9" class="data row4 col9" >Prospects: X</td>
#       <td id="T_5e347_row4_col10" class="data row4 col10" >X40</td>
#       <td id="T_5e347_row4_col11" class="data row4 col11" >3</td>
#       <td id="T_5e347_row4_col12" class="data row4 col12" >74.24</td>
#       <td id="T_5e347_row4_col13" class="data row4 col13" >25.70</td>
#       <td id="T_5e347_row4_col14" class="data row4 col14" >39.95%</td>
#       <td id="T_5e347_row4_col15" class="data row4 col15" >31.89%</td>
#       <td id="T_5e347_row4_col16" class="data row4 col16" >15.62</td>
#       <td id="T_5e347_row4_col17" class="data row4 col17" >-39.22%</td>
#     </tr>
#     <tr>
#       <td id="T_5e347_row5_col0" class="data row5 col0" >VBL</td>
#       <td id="T_5e347_ro
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">L — Low Conviction Review</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Non-prospect holdings are deliberately retained and explicitly identified.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_8e3dd" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8e3dd_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_8e3dd_level0_col1" class="col_heading level0 col1" >Shares</th>
#       <th id="T_8e3dd_level0_col2" class="col_heading level0 col2" >Investment</th>
#       <th id="T_8e3dd_level0_col3" class="col_heading level0 col3" >Prospect Status</th>
#       <th id="T_8e3dd_level0_col4" class="col_heading level0 col4" >Conviction</th>
#       <th id="T_8e3dd_level0_col5" class="col_heading level0 col5" >CapType</th>
#       <th id="T_8e3dd_level0_col6" class="col_heading level0 col6" >Assessment Basis</th>
#       <th id="T_8e3dd_level0_col7" class="col_heading level0 col7" >Criteria</th>
#       <th id="T_8e3dd_level0_col8" class="col_heading level0 col8" >CumlRnk</th>
#       <th id="T_8e3dd_level0_col9" class="col_heading level0 col9" >EPS</th>
#       <th id="T_8e3dd_level0_col10" class="col_heading level0 col10" >MedPE</th>
#       <th id="T_8e3dd_level0_col11" class="col_heading level0 col11" >ROCE%</th>
#       <th id="T_8e3dd_level0_col12" class="col_heading level0 col12" >ROE%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8e3dd_row0_col0" class="data row0 col0" >RAJESHEXPO</td>
#       <td id="T_8e3dd_row0_col1" class="data row0 col1" >265</td>
#       <td id="T_8e3dd_row0_col2" class="data row0 col2" >1,37,176</td>
#       <td id="T_8e3dd_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_8e3dd_row0_col4" class="data row0 col4" >L</td>
#       <td id="T_8e3dd_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_8e3dd_row0_col6" class="data row0 col6" >Prospects: L</td>
#       <td id="T_8e3dd_row0_col7" class="data row0 col7" >OX40N</td>
#       <td id="T_8e3dd_row0_col8" class="data row0 col8" >268</td>
#       <td id="T_8e3dd_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_8e3dd_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_8e3dd_row0_col11" class="data row0 col11" >nan%</td>
#       <td id="T_8e3dd_row0_col12" class="data row0 col12" >nan%</td>
#     </tr>
#     <tr>
#       <td id="T_8e3dd_row1_col0" class="data row1 col0" >COFFEEDAY</td>
#       <td id="T_8e3dd_row1_col1" class="data row1 col1" >1920</td>
#       <td id="T_8e3dd_row1_col2" class="data row1 col2" >1,13,544</td>
#       <td id="T_8e3dd_row1_col3" class="data row1 col3" >Yes</td>
#       <td id="T_8e3dd_row1_col4" class="data row1 col4" >L</td>
#       <td id="T_8e3dd_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_8e3dd_row1_col6" class="data row1 col6" >Prospects: L</td>
#       <td id="T_8e3dd_row1_col7" class="data row1 col7" >XR</td>
#       <td id="T_8e3dd_row1_col8" class="data row1 col8" >266</td>
#       <td id="T_8e3dd_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_8e3dd_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_8e3dd_row1_col11" class="data row1 col11" >nan%</td>
#       <td id="T_8e3dd_row1_col12" class="data row1 col12" >nan%</td>
#     </tr>
#     <tr>
#       <td id="T_8e3dd_row2_col0" class="data row2 col0" >INDUSINDBK</td>
#       <td id="T_8e3dd_row2_col1" class="data row2 col1" >57</td>
#       <td id="T_8e3dd_row2_col2" class="data row2 col2" >77,206</td>
#       <td id="T_8e3dd_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_8e3dd_row2_col4" class="data row2 col4" >L</td>
#       <td id="T_8e3dd_row2_col5" class="data row2 col5" >MC</td>
#       <td id="T_8e3dd_row2_col6" class="data row2 col6" >Prospects: L</td>
#       <td id="T_8e3dd_row2_col7" class="data row2 col7" >XR</td>
#       <td id="T_8e3dd_row2_col8" class="data row2 col8" >258</td>
#       <td id="T_8e3dd_row2_col9" class="data row2 col9" >16.970000</td>
#       <td id="T_8e3dd_row2_col10" class="data row2 col10" >14.040000</td>
#       <td id="T_8e3dd_row2_col11" class="data row2 col11" >5.68%</td>
#       <td id="T_8e3dd_row2_col12" class="data row2 col12" >1.36%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Why is this holding X / H / M / L?</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Select a holding to inspect its classification basis and available evidence.</div>
#     </div>
# Dropdown(description='Holding:', layout=Layout(width='420px'), options=('5PAISA', 'ABBOTINDIA', 'ACC', 'ALKYLA…
# Output()

# %% [markdown]
# ---
# ## 4. Interactive Action Center
#
# Choose a review queue below. The underlying candidates are the same five-stock views produced by the original notebook, now surfaced as an action-oriented terminal.

# %%
# ============================================================
# INTERACTIVE ACTION CENTER
# ============================================================

action_selector = widgets.Dropdown(
    options=ACTION_VIEW_OPTIONS,
    value="Near Target",
    description="Review queue:",
    layout=widgets.Layout(width="520px"),
    style={"description_width": "110px"}
)

action_output = widgets.Output()

def render_action_queue(change=None):
    with action_output:
        clear_output(wait=True)
        queue = action_selector.value
        dfq = ACTION_VIEWS[queue]
        action, reason = ACTION_META[queue]

        display(HTML(f"""
        <div style="padding:16px 18px;border-radius:14px;background:#f8fafc;
                    border:1px solid #e2e8f0;font-family:Inter,Arial,sans-serif;">
            <div style="font-size:18px;font-weight:800;color:#111827;">{action}</div>
            <div style="font-size:13px;color:#64748b;margin-top:5px;">{reason}</div>
        </div>
        """))

        if dfq.empty:
            display(HTML('<p style="color:#64748b;">No candidates match this queue.</p>'))
            return

        _show_table(dfq, max_rows=5)

action_selector.observe(render_action_queue, names="value")
display(action_selector)
display(action_output)
render_action_queue()
# Out:
# Dropdown(description='Review queue:', layout=Layout(width='520px'), options=('Near Target', 'Accumulate', "Tod…
# Output()

# %% [markdown]
# ---
# ## 5. Stock Drill-down
#
# Select any holding to move from the portfolio-level signal to the evidence behind that stock.

# %%
# ============================================================
# STOCK DRILL-DOWN
# ============================================================

stock_selector = widgets.Dropdown(
    options=sorted(df_portfolio_features['Symbol'].dropna().unique().tolist()),
    description="Holding:",
    layout=widgets.Layout(width="420px"),
    style={"description_width": "75px"}
)
stock_output = widgets.Output()

def render_stock(change=None):
    with stock_output:
        clear_output(wait=True)
        symbol = stock_selector.value
        row = df_portfolio_features[df_portfolio_features['Symbol'] == symbol].iloc[0]

        cards = [
            _card("Current", _money(row.get('Current', np.nan)), f"Allocation {_pct(row.get('CurrAlloc%', np.nan))}"),
            _card("Current P/L", _pct(row.get('Current P/L%', np.nan)), _money(row.get('Current P/L', np.nan))),
            _card("FTT", _pct(row.get('FTT%', np.nan)), _money(row.get('FTT Amt', np.nan))),
            _card("RSI", str(row.get('RSI_14', '—')), "14-period"),
            _card("Rank", str(row.get('CumlRnk', '—')), "Cumulative rank"),
        ]
        display(HTML('<div style="display:flex;flex-wrap:wrap;margin:-6px;">' + ''.join(cards) + '</div>'))

        evidence_cols = [
            'Symbol','Conviction','Criteria','Strategy','Category','AvgCost','Shares',
            'Close','Target','NTT','LTT','CurrAlloc%','Current P/L%','Today P/L%',
            'FTT%','Dev%_PE','Dev%_200','Spread%','Gained%','RSP','RRR Ind','Risk Ind'
        ]
        evidence_cols = [c for c in evidence_cols if c in row.index]
        evidence = pd.DataFrame([row[evidence_cols].to_dict()])
        evidence = evidence.T.rename(columns={0:'Value'})

        if 'Value' in evidence.columns:
            if 'RSI_14' in evidence.index:
                evidence.loc['RSI_14', 'Value'] = f"{float(evidence.loc['RSI_14', 'Value']):.0f}"
            if 'CumlRnk' in evidence.index:
                evidence.loc['CumlRnk', 'Value'] = f"{float(evidence.loc['CumlRnk', 'Value']):.0f}"
            if 'RRR Ind' in evidence.index:
                evidence.loc['RRR Ind', 'Value'] = f"{float(evidence.loc['RRR Ind', 'Value']):.2f}"

            for metric in evidence.index:
                if '%' in metric:
                    try:
                        evidence.loc[metric, 'Value'] = f"{float(evidence.loc[metric, 'Value']):.2f}%"
                    except Exception:
                        pass

            for metric in ['AvgCost', 'Close', 'Target', 'NTT', 'LTT']:
                if metric in evidence.index:
                    evidence.loc[metric, 'Value'] = _indian_number(evidence.loc[metric, 'Value'])

        display(evidence)

stock_selector.observe(render_stock, names="value")
display(stock_selector)
display(stock_output)
render_stock()
# Out:
# Dropdown(description='Holding:', layout=Layout(width='420px'), options=('5PAISA', 'ABBOTINDIA', 'ACC', 'ALKYLA…
# Output()

# %% [markdown]
# ---
# ## 6. Allocation & Opportunity Views
#
# The following views preserve the original notebook's portfolio-shape analyses, but make them easier to interpret.

# %%
# ============================================================
# ALLOCATION / OPPORTUNITY TABLES
# ============================================================

top_n_values = [10, 25, 50]
sum_df = pd.DataFrame({
    'Top_N': top_n_values,
    'Sum_Alloc%': [
        df_portfolio_features.sort_values('CurrAlloc%', ascending=False)['CurrAlloc%'].head(n).sum()
        for n in top_n_values
    ]
})

display(_section("Concentration", "How much of current allocation sits in the largest N holdings?"))
display(sum_df.style.format({'Sum_Alloc%':'{:.2f}%'}).hide(axis="index"))

cap_alloc = (
    df_portfolio_features.groupby(df_portfolio_features['Conviction'].str[-2:])['CurrAlloc%']
    .sum().sort_values(ascending=False).rename('Allocation %').reset_index()
)
display(_section("Market-cap allocation", "Existing Conviction suffix grouping."))
display(cap_alloc.style.format({'Allocation %':'{:.2f}%'}).hide(axis="index"))

criteria_alloc = (
    df_portfolio_features.groupby('Criteria')['CurrAlloc%']
    .sum().sort_values(ascending=False).rename('Allocation %').reset_index()
)
display(_section("Criteria allocation", "Current allocation by the existing criteria taxonomy."))
display(criteria_alloc.style.format({'Allocation %':'{:.2f}%'}).hide(axis="index"))

conviction_alloc = (
    df_portfolio_features.groupby('Conviction')['CurrAlloc%']
    .sum().sort_values(ascending=False).rename('Allocation %').reset_index()
)
display(_section("Conviction allocation", "Current allocation by conviction bucket."))
display(conviction_alloc.style.format({'Allocation %':'{:.2f}%'}).hide(axis="index"))

money_criteria = (
    df_portfolio_features.groupby('Criteria')['FTT Amt']
    .agg(['sum','count']).sort_values('sum', ascending=False)
    .rename(columns={'sum':'FTT Amt','count':'Holdings'}).reset_index()
)
money_conviction = (
    df_portfolio_features.groupby('Conviction')['FTT Amt']
    .agg(['sum','count']).sort_values('sum', ascending=False)
    .rename(columns={'sum':'FTT Amt','count':'Holdings'}).reset_index()
)

display(_section("Remaining FTT opportunity by criteria", "Existing FTT amount aggregation."))
display(money_criteria.style.format({'FTT Amt':lambda x: _indian_number(x)}).hide(axis="index"))

display(_section("Remaining FTT opportunity by conviction", "Existing FTT amount aggregation."))
display(money_conviction.style.format({'FTT Amt':lambda x: _indian_number(x)}).hide(axis="index"))
# Out:
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Concentration</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">How much of current allocation sits in the largest N holdings?</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_2f7cd" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_2f7cd_level0_col0" class="col_heading level0 col0" >Top_N</th>
#       <th id="T_2f7cd_level0_col1" class="col_heading level0 col1" >Sum_Alloc%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2f7cd_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_2f7cd_row0_col1" class="data row0 col1" >21.18%</td>
#     </tr>
#     <tr>
#       <td id="T_2f7cd_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_2f7cd_row1_col1" class="data row1 col1" >48.31%</td>
#     </tr>
#     <tr>
#       <td id="T_2f7cd_row2_col0" class="data row2 col0" >50</td>
#       <td id="T_2f7cd_row2_col1" class="data row2 col1" >79.45%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Market-cap allocation</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Existing Conviction suffix grouping.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_374c6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_374c6_level0_col0" class="col_heading level0 col0" >Conviction</th>
#       <th id="T_374c6_level0_col1" class="col_heading level0 col1" >Allocation %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_374c6_row0_col0" class="data row0 col0" >LC</td>
#       <td id="T_374c6_row0_col1" class="data row0 col1" >41.07%</td>
#     </tr>
#     <tr>
#       <td id="T_374c6_row1_col0" class="data row1 col0" >MC</td>
#       <td id="T_374c6_row1_col1" class="data row1 col1" >21.16%</td>
#     </tr>
#     <tr>
#       <td id="T_374c6_row2_col0" class="data row2 col0" >SC</td>
#       <td id="T_374c6_row2_col1" class="data row2 col1" >20.56%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Criteria allocation</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Current allocation by the existing criteria taxonomy.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_9596a" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_9596a_level0_col0" class="col_heading level0 col0" >Criteria</th>
#       <th id="T_9596a_level0_col1" class="col_heading level0 col1" >Allocation %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9596a_row0_col0" class="data row0 col0" >X40</td>
#       <td id="T_9596a_row0_col1" class="data row0 col1" >28.31%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row1_col0" class="data row1 col0" >XY24</td>
#       <td id="T_9596a_row1_col1" class="data row1 col1" >23.23%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row2_col0" class="data row2 col0" >X40N</td>
#       <td id="T_9596a_row2_col1" class="data row2 col1" >19.04%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row3_col0" class="data row3 col0" >XR</td>
#       <td id="T_9596a_row3_col1" class="data row3 col1" >9.55%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row4_col0" class="data row4 col0" >XY25</td>
#       <td id="T_9596a_row4_col1" class="data row4 col1" >7.50%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row5_col0" class="data row5 col0" >OX40N</td>
#       <td id="T_9596a_row5_col1" class="data row5 col1" >6.91%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row6_col0" class="data row6 col0" >AR</td>
#       <td id="T_9596a_row6_col1" class="data row6 col1" >4.62%</td>
#     </tr>
#     <tr>
#       <td id="T_9596a_row7_col0" class="data row7 col0" >SR</td>
#       <td id="T_9596a_row7_col1" class="data row7 col1" >0.86%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Conviction allocation</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Current allocation by conviction bucket.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_fe080" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_fe080_level0_col0" class="col_heading level0 col0" >Conviction</th>
#       <th id="T_fe080_level0_col1" class="col_heading level0 col1" >Allocation %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe080_row0_col0" class="data row0 col0" >X-LC</td>
#       <td id="T_fe080_row0_col1" class="data row0 col1" >38.15%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row1_col0" class="data row1 col0" >X-MC</td>
#       <td id="T_fe080_row1_col1" class="data row1 col1" >18.71%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row2_col0" class="data row2 col0" >H-SC</td>
#       <td id="T_fe080_row2_col1" class="data row2 col1" >8.03%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row3_col0" class="data row3 col0" >X-SC</td>
#       <td id="T_fe080_row3_col1" class="data row3 col1" >7.33%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row4_col0" class="data row4 col0" >M-SC</td>
#       <td id="T_fe080_row4_col1" class="data row4 col1" >5.20%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row5_col0" class="data row5 col0" >H-LC</td>
#       <td id="T_fe080_row5_col1" class="data row5 col1" >1.62%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row6_col0" class="data row6 col0" >M-LC</td>
#       <td id="T_fe080_row6_col1" class="data row6 col1" >1.30%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row7_col0" class="data row7 col0" >M-MC</td>
#       <td id="T_fe080_row7_col1" class="data row7 col1" >1.11%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row8_col0" class="data row8 col0" >H-MC</td>
#       <td id="T_fe080_row8_col1" class="data row8 col1" >0.98%</td>
#     </tr>
#     <tr>
#       <td id="T_fe080_row9_col0" class="data row9 col0" >L-MC</td>
#       <td id="T_fe080_row9_col1" class="data row9 col1" >0.36%</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Remaining FTT opportunity by criteria</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Existing FTT amount aggregation.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_61ad9" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_61ad9_level0_col0" class="col_heading level0 col0" >Criteria</th>
#       <th id="T_61ad9_level0_col1" class="col_heading level0 col1" >FTT Amt</th>
#       <th id="T_61ad9_level0_col2" class="col_heading level0 col2" >Holdings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_61ad9_row0_col0" class="data row0 col0" >XY24</td>
#       <td id="T_61ad9_row0_col1" class="data row0 col1" >37,88,231</td>
#       <td id="T_61ad9_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row1_col0" class="data row1 col0" >X40</td>
#       <td id="T_61ad9_row1_col1" class="data row1 col1" >23,30,062</td>
#       <td id="T_61ad9_row1_col2" class="data row1 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row2_col0" class="data row2 col0" >XR</td>
#       <td id="T_61ad9_row2_col1" class="data row2 col1" >15,58,248</td>
#       <td id="T_61ad9_row2_col2" class="data row2 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row3_col0" class="data row3 col0" >X40N</td>
#       <td id="T_61ad9_row3_col1" class="data row3 col1" >13,50,841</td>
#       <td id="T_61ad9_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row4_col0" class="data row4 col0" >AR</td>
#       <td id="T_61ad9_row4_col1" class="data row4 col1" >10,73,698</td>
#       <td id="T_61ad9_row4_col2" class="data row4 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row5_col0" class="data row5 col0" >OX40N</td>
#       <td id="T_61ad9_row5_col1" class="data row5 col1" >7,06,141</td>
#       <td id="T_61ad9_row5_col2" class="data row5 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row6_col0" class="data row6 col0" >XY25</td>
#       <td id="T_61ad9_row6_col1" class="data row6 col1" >6,70,291</td>
#       <td id="T_61ad9_row6_col2" class="data row6 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_61ad9_row7_col0" class="data row7 col0" >SR</td>
#       <td id="T_61ad9_row7_col1" class="data row7 col1" >2,80,249</td>
#       <td id="T_61ad9_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="margin:24px 4px 10px; font-family:Inter,Arial,sans-serif;">
#         <div style="font-size:22px;font-weight:800;color:#111827;">Remaining FTT opportunity by conviction</div>
#         <div style="font-size:13px;color:#6b7280;margin-top:4px;">Existing FTT amount aggregation.</div>
#     </div>
# <style type="text/css">
# </style>
# <table id="T_ce213" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_ce213_level0_col0" class="col_heading level0 col0" >Conviction</th>
#       <th id="T_ce213_level0_col1" class="col_heading level0 col1" >FTT Amt</th>
#       <th id="T_ce213_level0_col2" class="col_heading level0 col2" >Holdings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ce213_row0_col0" class="data row0 col0" >X-LC</td>
#       <td id="T_ce213_row0_col1" class="data row0 col1" >28,74,422</td>
#       <td id="T_ce213_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row1_col0" class="data row1 col0" >X-MC</td>
#       <td id="T_ce213_row1_col1" class="data row1 col1" >15,68,087</td>
#       <td id="T_ce213_row1_col2" class="data row1 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row2_col0" class="data row2 col0" >X-SC</td>
#       <td id="T_ce213_row2_col1" class="data row2 col1" >11,22,849</td>
#       <td id="T_ce213_row2_col2" class="data row2 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row3_col0" class="data row3 col0" >H-SC</td>
#       <td id="T_ce213_row3_col1" class="data row3 col1" >8,91,067</td>
#       <td id="T_ce213_row3_col2" class="data row3 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row4_col0" class="data row4 col0" >M-SC</td>
#       <td id="T_ce213_row4_col1" class="data row4 col1" >3,48,710</td>
#       <td id="T_ce213_row4_col2" class="data row4 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row5_col0" class="data row5 col0" >M-LC</td>
#       <td id="T_ce213_row5_col1" class="data row5 col1" >2,79,352</td>
#       <td id="T_ce213_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row6_col0" class="data row6 col0" >H-MC</td>
#       <td id="T_ce213_row6_col1" class="data row6 col1" >2,59,620</td>
#       <td id="T_ce213_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row7_col0" class="data row7 col0" >M-MC</td>
#       <td id="T_ce213_row7_col1" class="data row7 col1" >71,255</td>
#       <td id="T_ce213_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row8_col0" class="data row8 col0" >L-MC</td>
#       <td id="T_ce213_row8_col1" class="data row8 col1" >46,855</td>
#       <td id="T_ce213_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ce213_row9_col0" class="data row9 col0" >H-LC</td>
#       <td id="T_ce213_row9_col1" class="data row9 col1" >28,900</td>
#       <td id="T_ce213_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 7. Action Review Checklist
#
# Before acting on any portfolio signal:
#
# 1. **Start with the dashboard** — current value, P/L, XIRR and FTT upside.
# 2. **Open the relevant action queue** — understand why a stock is being surfaced.
# 3. **Drill into the holding** — inspect allocation, rank, RSI, PE deviation, spread and FTT.
# 4. **Check concentration** — understand whether the action changes portfolio balance.
# 5. **Review the source data / strategy rules** before making a decision.
# 6. **Treat every action as a review prompt**, not an automatic order.
#
# ### Data lineage
# **User portfolio CSV → Prospects + Screener → Holding Quality Assessment → existing portfolio rules → visual intelligence layer**
#
# The presentation layer does not replace the existing calculations.

# %%
# ============================================================
# RUN FOOTER
# ============================================================

end_time = time.time()
execution_time = round(end_time - start_time, 0)

display(HTML(f"""
<div style="margin-top:28px;padding:16px 20px;border-radius:12px;
            background:#f8fafc;border:1px solid #e2e8f0;
            font-family:Inter,Arial,sans-serif;color:#64748b;">
    <b style="color:#111827;">Terminal run complete.</b>
    &nbsp; Execution time: {execution_time:.0f} seconds
    &nbsp;·&nbsp; Data window: {start_date} → {end_date}
    &nbsp;·&nbsp; Run date: {datetime.date.today().strftime('%d %b %Y')}
</div>
"""))
# Out:
# <div style="margin-top:28px;padding:16px 20px;border-radius:12px;
#             background:#f8fafc;border:1px solid #e2e8f0;
#             font-family:Inter,Arial,sans-serif;color:#64748b;">
#     <b style="color:#111827;">Terminal run complete.</b>
#     &nbsp; Execution time: 38 seconds
#     &nbsp;·&nbsp; Data window: 2025-09-02 → 2026-09-03
#     &nbsp;·&nbsp; Run date: 02 Sep 2026
# </div>
